# %% [markdown]
# # Collect fitted parameters for bivariate models in all months in a single table for supplementary material

# %%
import pandas as pd

# %%
months = ["202102", "202104", "202107", "202110"]

models = []
for m in months:
    df_params = pd.read_csv(f"../data/intermediate/models/{m}/bivariate_model.csv", index_col=0)
    df_params["month"] = m
    models.append(df_params)

df = (
    pd.concat(models, axis=0)
    .reset_index(drop=True)
    .rename(columns={"name": "parameter"})[["month", "parameter", "value", "bounds"]]
)
df
# Out:
#      month     parameter       value          bounds
# 0   202102      sigma_11    0.470577      (0.4, 3.5)
# 1   202102      sigma_22    0.832327      (0.4, 3.5)
# 2   202102         nu_11    0.300000      (0.3, 1.0)
# 3   202102         nu_12    1.500000      (0.5, 1.5)
# 4   202102         nu_22    1.000000      (0.3, 1.0)
# 5   202102  len_scale_11   52.065301       (10, 300)
# 6   202102  len_scale_12  100.357662       (10, 300)
# 7   202102  len_scale_22   77.299462       (10, 300)
# 8   202102     nugget_11    0.783041      (0.0, 0.9)
# 9   202102     nugget_22    0.337302      (0.0, 0.9)
# 10  202102        rho_12    0.016452      (1e-08, 1)
# 11  202104      sigma_11    0.476928      (0.4, 3.5)
# 12  202104      sigma_22    0.744106      (0.4, 3.5)
# 13  202104         nu_11    0.999948      (0.3, 1.0)
# 14  202104         nu_12    1.500000      (0.5, 1.5)
# 15  202104         nu_22    0.657173      (0.3, 1.0)
# 16  202104  len_scale_11   36.029455       (10, 300)
# 17  202104  len_scale_12  100.000982       (10, 300)
# 18  202104  len_scale_22   61.353455       (10, 300)
# 19  202104     nugget_11    0.751419      (0.0, 0.9)
# 20  202104     nugget_22    0.417503      (0.0, 0.9)
# 21  202104        rho_12    0.027004    (1e-08, 1.0)
# 22  202107      sigma_11    0.614700      (0.4, 3.5)
# 23  202107      sigma_22    0.918658      (0.4, 3.5)
# 24  202107         nu_11    1.000000      (0.3, 1.0)
# 25  202107         nu_12    1.300000      (1.3, 2.3)
# 26  202107         nu_22    1.000000      (0.3, 1.0)
# 27  202107  len_scale_11   87.555756       (10, 300)
# 28  202107  len_scale_12  300.000000       (10, 300)
# 29  202107  len_scale_22   62.439550       (10, 300)
# 30  202107     nugget_11    0.630879      (0.0, 0.9)
# 31  202107     nugget_22    0.255551      (0.0, 0.9)
# 32  202107        rho_12   -0.130629    (-1, -1e-08)
# 33  202110      sigma_11    0.466716      (0.4, 3.5)
# 34  202110      sigma_22    0.826628      (0.4, 3.5)
# 35  202110         nu_11    0.451143      (0.3, 1.0)
# 36  202110         nu_12    0.751583      (0.3, 1.5)
# 37  202110         nu_22    1.000000      (0.3, 1.0)
# 38  202110  len_scale_11   50.502538       (10, 300)
# 39  202110  len_scale_12   65.957046       (10, 300)
# 40  202110  len_scale_22   70.136391       (10, 300)
# 41  202110     nugget_11    0.717478      (0.0, 0.9)
# 42  202110     nugget_22    0.349238      (0.0, 0.9)
# 43  202110        rho_12   -0.100000  (-0.1, -1e-08)

# %%
df.to_csv("../data/output/fitted_model_parameters.csv")
