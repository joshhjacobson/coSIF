# %% [markdown]
# # Within-sample validation against withheld validation block
#
# Leave out a block of data and predict the withheld data. Models include cokriging, kriging,
# and trend-only prediction

# %%
import sys

sys.path.insert(0, "../../source")

# %%
from copy import deepcopy
import pickle
import numpy as np
import pandas as pd
import xarray as xr
import statsmodels.api as sm

import matplotlib.pyplot as plt
import seaborn as sns

import plot
import prediction
import validation

# %%
from dask.distributed import Client

# NOTE: update depending on which node is used
N_WORKERS = 84
client = Client(n_workers=N_WORKERS)
# Out:
# /home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/node.py:183: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 39385 instead
#   warnings.warn(
# 2023-06-13 13:18:31,109 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-jgx_x2fm', purging
# 2023-06-13 13:18:31,109 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-jg5pzybh', purging
# 2023-06-13 13:18:31,109 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-3jah6lon', purging
# 2023-06-13 13:18:31,110 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-qmhgf7r_', purging
# 2023-06-13 13:18:31,110 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-hjlj4y57', purging
# 2023-06-13 13:18:31,110 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-wzgr7y34', purging
# 2023-06-13 13:18:31,110 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-lzkka9he', purging
# 2023-06-13 13:18:31,110 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-uqdqngad', purging
# 2023-06-13 13:18:31,110 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-7che4gjh', purging
# 2023-06-13 13:18:31,110 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-o98wgl0w', purging
# 2023-06-13 13:18:31,110 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-pxv1ogke', purging
# 2023-06-13 13:18:31,110 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-av09e_u3', purging
# 2023-06-13 13:18:31,110 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-xrfiaaxk', purging
# 2023-06-13 13:18:31,110 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-8r2tpiew', purging
# 2023-06-13 13:18:31,110 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-wvswd5k2', purging
# 2023-06-13 13:18:31,110 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-yybwr10i', purging
# 2023-06-13 13:18:31,110 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-mrwq3x0p', purging
# 2023-06-13 13:18:31,111 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-moggn56j', purging
# 2023-06-13 13:18:31,111 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-_9_agpqy', purging
# 2023-06-13 13:18:31,111 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-5d8i5a5h', purging
# 2023-06-13 13:18:31,111 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-e6r8ck1s', purging
# 2023-06-13 13:18:31,111 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-sp1i90j0', purging
# 2023-06-13 13:18:31,111 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-3f98neyw', purging
# 2023-06-13 13:18:31,111 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-yx4aw4kv', purging
# 2023-06-13 13:18:31,111 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-s_59lvwp', purging
# 2023-06-13 13:18:31,111 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-6u05ex86', purging
# 2023-06-13 13:18:31,111 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-v8iwkz6v', purging
# 2023-06-13 13:18:31,111 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-odsiaa0e', purging
# 2023-06-13 13:18:31,111 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-0raj_5cj', purging
# 2023-06-13 13:18:31,111 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-sr8qhgqh', purging
# 2023-06-13 13:18:31,111 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-pqxcbhje', purging
# 2023-06-13 13:18:31,111 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-d7s120wb', purging
# 2023-06-13 13:18:31,112 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-b4onyuv8', purging
# 2023-06-13 13:18:31,112 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-o07mbo0b', purging
# 2023-06-13 13:18:31,112 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-33kluezm', purging
# 2023-06-13 13:18:31,112 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-qay9p50g', purging
# 2023-06-13 13:18:31,112 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-6ibmodj1', purging
# 2023-06-13 13:18:31,112 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-6jg7yps7', purging
# 2023-06-13 13:18:31,112 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-gb6udhnz', purging
# 2023-06-13 13:18:31,112 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-m73cps_6', purging
# 2023-06-13 13:18:31,112 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-qe5siblq', purging
# 2023-06-13 13:18:31,112 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-tq8r6qlz', purging
# 2023-06-13 13:18:31,112 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-63w7wdn1', purging
# 2023-06-13 13:18:31,112 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ny3jb8i8', purging
# 2023-06-13 13:18:31,112 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-wxr0fk53', purging
# 2023-06-13 13:18:31,112 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-byu3w5r7', purging
# 2023-06-13 13:18:31,113 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-mvdtqf9j', purging
# 2023-06-13 13:18:31,113 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-6silwni1', purging
# 2023-06-13 13:18:31,113 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-xt_yct58', purging
# 2023-06-13 13:18:31,113 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-tcwb63h2', purging
# 2023-06-13 13:18:31,113 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-kxm5imat', purging
# 2023-06-13 13:18:31,113 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-erse9haq', purging
# 2023-06-13 13:18:31,113 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-2r3l6ux_', purging
# 2023-06-13 13:18:31,113 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-5dokz05_', purging
# 2023-06-13 13:18:31,113 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-cuo1edkq', purging
# 2023-06-13 13:18:31,113 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-kfkb9065', purging
# 2023-06-13 13:18:31,113 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ga2kqhsx', purging
# 2023-06-13 13:18:31,113 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ymvtp5sv', purging
# 2023-06-13 13:18:31,113 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-mvcwq43m', purging
# 2023-06-13 13:18:31,113 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-hy0ncmqv', purging
# 2023-06-13 13:18:31,114 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-1swtk9r3', purging
# 2023-06-13 13:18:31,114 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-gsf3_jud', purging
# 2023-06-13 13:18:31,114 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-lnuh0uie', purging
# 2023-06-13 13:18:31,114 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-eeh89j6z', purging
# 2023-06-13 13:18:31,114 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-c98cglcq', purging
# 2023-06-13 13:18:31,114 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-rtylrzmz', purging
# 2023-06-13 13:18:31,114 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-x3l9ezpj', purging
# 2023-06-13 13:18:31,114 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ufo7ozn2', purging
# 2023-06-13 13:18:31,114 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-fhjxb0hs', purging
# 2023-06-13 13:18:31,114 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-_g2cwfay', purging
# 2023-06-13 13:18:31,114 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-u_gymrh3', purging
# 2023-06-13 13:18:31,114 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-wbl9wnym', purging
# 2023-06-13 13:18:31,114 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-1xmmvq1j', purging
# 2023-06-13 13:18:31,114 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-797k0iem', purging
# 2023-06-13 13:18:31,115 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-qw2hrfvy', purging
# 2023-06-13 13:18:31,115 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-5k2cubho', purging
# 2023-06-13 13:18:31,115 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-4nzz5xd7', purging
# 2023-06-13 13:18:31,115 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-i1lvuknc', purging
# 2023-06-13 13:18:31,115 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-q9upetij', purging
# 2023-06-13 13:18:31,115 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-_o0wa4aa', purging
# 2023-06-13 13:18:31,115 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-yxdrcius', purging
# 2023-06-13 13:18:31,115 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-0ltsyoli', purging
# 2023-06-13 13:18:31,115 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-tef7ojw4', purging
# 2023-06-13 13:18:31,115 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ww0zqmks', purging

# %%
# number of nearest observations used in point predictions
NUM_LOCAL_VALUES = 150

# data selection
YEAR = 2021
MONTH = 4
# XCO2 months ahead of SIF
OFFSET = 1

year_month_str = f"{YEAR}0{MONTH}" if MONTH < 10 else f"{YEAR}{MONTH}"

# %%
month_xco2 = MONTH + OFFSET
date_sif = f"{YEAR}-{MONTH}-01"
date_xco2 = f"{YEAR}-{month_xco2}-01"

with xr.open_dataset(
    "../../data/intermediate/OCO2_005deg_monthly_north_america_with_basis.nc4"
) as ds:
    basis_vars = [x for x in list(ds.keys()) if x.startswith("B")]
    ds_sif = ds[["sif", "sif_var"] + basis_vars].sel(time=f"{YEAR}-{MONTH}").squeeze()

# %%
BLOCK_NAME = "b2"
block_conditions = (
    (ds_sif["lon"] > -104)
    & (ds_sif["lon"] < -99)
    & (ds_sif["lat"] > 36.5)
    & (ds_sif["lat"] < 41.5)
)
ds_test = ds_sif.where(block_conditions)

plot.plot_da(ds_test["sif"])

# %%
df_test = (
    ds_test.to_dataframe()
    .dropna(subset="sif")
    .reset_index()[["lat", "lon", "sif", "sif_var"] + basis_vars]
    .rename(columns={"sif": "data", "sif_var": "me_variance"})
)
df_me_variance = df_test.loc[:, ["lat", "lon", "me_variance"]]
df_test = df_test.drop(columns="me_variance")
ds_covariates = (
    df_test.set_index(["lat", "lon"]).to_xarray().drop_vars(["data", "B1", "B10", "B20"])
)
df_test = df_test.loc[:, ["lat", "lon", "data"]]
pcoords = df_test.loc[:, ["lat", "lon"]]
df_test.to_csv(f"../../data/intermediate/validation/{year_month_str}/df_test_{BLOCK_NAME}.csv")
df_test
# Out:
#         lat      lon      data
# 0    36.525 -103.775 -0.103662
# 1    36.525 -103.725  0.456368
# 2    36.525 -103.025  0.373465
# 3    36.525 -101.475  0.286165
# 4    36.525 -100.825  0.915663
# ..      ...      ...       ...
# 589  41.475 -101.425 -0.117198
# 590  41.475  -99.925  0.777075
# 591  41.475  -99.875  1.162170
# 592  41.475  -99.325  0.538670
# 593  41.475  -99.275  0.836137
#
# [594 rows x 3 columns]

# %%
ds_covariates
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 100, lon: 96)
# Coordinates:
#   * lat      (lat) float64 36.52 36.57 36.62 36.67 ... 41.32 41.37 41.42 41.47
#   * lon      (lon) float64 -104.0 -103.9 -103.9 -103.8 ... -99.12 -99.07 -99.02
# Data variables: (12/57)
#     B2       (lat, lon) float64 nan nan nan nan 0.0 0.0 ... nan nan nan nan nan
#     B3       (lat, lon) float64 nan nan nan nan 0.0 0.0 ... nan nan nan nan nan
#     B4       (lat, lon) float64 nan nan nan nan 0.0 0.0 ... nan nan nan nan nan
#     B5       (lat, lon) float64 nan nan nan nan 0.0 0.0 ... nan nan nan nan nan
#     B6       (lat, lon) float64 nan nan nan nan 0.0 0.0 ... nan nan nan nan nan
#     B7       (lat, lon) float64 nan nan nan nan 0.0 0.0 ... nan nan nan nan nan
#     ...       ...
#     B55      (lat, lon) float64 nan nan nan nan 0.0 0.0 ... nan nan nan nan nan
#     B56      (lat, lon) float64 nan nan nan nan 0.0 0.0 ... nan nan nan nan nan
#     B57      (lat, lon) float64 nan nan nan nan 0.0 0.0 ... nan nan nan nan nan
#     B58      (lat, lon) float64 nan nan nan nan 0.0 0.0 ... nan nan nan nan nan
#     B59      (lat, lon) float64 nan nan nan nan 0.0 0.0 ... nan nan nan nan nan
#     B60      (lat, lon) float64 nan nan nan nan 0.0 0.0 ... nan nan nan nan nan

# %%
sns.histplot(df_test["data"].values)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ## Cokriging

# %%
# Load multifield and model objects
with open(f"../../data/intermediate/models/{year_month_str}/fields.pickle", "rb") as f:
    mf = pickle.load(f)

with open(f"../../data/intermediate/models/{year_month_str}/bivariate_model.pickle", "rb") as f:
    bivariate_matern = pickle.load(f)

# %%
# Make validation predictions
cokrige = prediction.Predictor(bivariate_matern, mf)
dict_cokrige = cokrige.validation_prediction(
    0,
    pcoords,
    df_me_variance,
    ds_covariates,
    num_local_values=NUM_LOCAL_VALUES,
)
ds_cokrige = dict_cokrige["ds"]
ds_cokrige
# Out:
# INFO | root:_compute_prediction_covariance_matrix:475 | Running predictive covariance
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 0 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 500 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 300 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 100 ...
# 2023-06-13 13:22:16,058 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.20 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:22:16,149 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.25 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:22:16,245 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.34 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:22:16,454 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.56 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:22:16,455 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.56 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:22:16,549 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.66 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:22:17,178 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.37 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:22:17,179 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.37 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:22:17,293 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.48 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:22:17,378 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.55 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:22:17,478 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.66 GiB -- Worker memory limit: 5.99 GiB
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 400 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 200 ...
# <xarray.Dataset>
# Dimensions:               (lat: 100, lon: 96)
# Coordinates:
#   * lat                   (lat) float64 36.52 36.57 36.62 ... 41.37 41.42 41.47
#   * lon                   (lon) float64 -104.0 -103.9 -103.9 ... -99.07 -99.02
#     time                  <U9 '2021-4-01'
# Data variables: (12/66)
#     residual_predictions  (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     residual_uncertainty  (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     validity_flag         (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B2                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B3                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B4                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     ...                    ...
#     trend_surface         (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     me_variance           (lat, lon) float32 nan nan nan nan ... nan nan nan nan
#     predictions           (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     scaled_residuals      (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     trend_surface_rmspe   (lat, lon) float32 0.06272 0.06272 ... 0.06272 0.06272
#     rmspe                 (lat, lon) float64 nan nan nan nan ... nan nan nan nan
# Attributes:
#     timedeltas:        [0, 1]
#     num_local_values:  150

# %%
# Save multivariate predictive distribution
pd.DataFrame(dict_cokrige["predictive_mean"]).to_csv(
    f"../../data/intermediate/validation/{year_month_str}/mean_cokriging_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)

pd.DataFrame(dict_cokrige["predictive_covariance_matrix"]).to_csv(
    f"../../data/intermediate/validation/{year_month_str}/covariance_cokriging_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)

# %%
# Prepare validation results
df_cokrige = (
    ds_cokrige.to_dataframe().reset_index()[["lat", "lon", "predictions", "rmspe"]].dropna()
)

df_test_cokrige = validation.prepare_validation_results(
    df_cokrige,
    df_test,
    method="cokriging",
    month=year_month_str,
    region=BLOCK_NAME,
)

# Compute QQ-plot quantiles
quantiles_cokrige = sm.ProbPlot(df_test_cokrige["ratio"].values)
df_quantiles_cokrige = pd.DataFrame(
    dict(
        sample=quantiles_cokrige.sample_quantiles,
        theoretical=quantiles_cokrige.theoretical_quantiles,
        Method="Cokriging",
    )
)

# %% [markdown]
# ## Kriging

# %%
client.close()
# Out:
# 2023-06-13 13:23:00,802 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:38020 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,809 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37768 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,820 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37576 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,838 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37420 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,855 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37704 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,865 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37858 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,871 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37500 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,894 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37444 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,897 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37966 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,900 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37520 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,904 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37750 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,907 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37534 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,925 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37664 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,936 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37634 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,937 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37600 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,940 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37996 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,945 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37364 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,948 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37498 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,951 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37940 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,959 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37646 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,977 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37370 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,992 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37506 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,988 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37730 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,995 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:38000 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,991 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37594 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,995 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37336 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:00,998 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# ...
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37838 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:01,163 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37454 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:01,328 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37792 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:01,372 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37666 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:01,385 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37398 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:01,395 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37698 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:01,395 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37980 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:01,560 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37392 remote=tcp://127.0.0.1:39245>: Stream is closed
# 2023-06-13 13:23:01,578 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37832 remote=tcp://127.0.0.1:39245>: Stream is closed

# %%
client = Client(n_workers=N_WORKERS)
# Out:
# /home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/node.py:183: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 32853 instead
#   warnings.warn(

# %%
# Isolate SIF field only
mf_univariate = deepcopy(mf)
mf_univariate.fields = np.array([mf_univariate.fields[0]])
mf_univariate.n_procs = 1

# Load univariate model
with open(
    f"../../data/intermediate/models/{year_month_str}/univariate_model.pickle", "rb"
) as f:
    univariate_matern = pickle.load(f)

# %%
# Make validation predictions
krige = prediction.Predictor(univariate_matern, mf_univariate)
dict_krige = krige.validation_prediction(
    0,
    pcoords,
    df_me_variance,
    ds_covariates,
    num_local_values=NUM_LOCAL_VALUES,
)
ds_krige = dict_krige["ds"]
ds_krige
# Out:
# INFO | root:_compute_prediction_covariance_matrix:475 | Running predictive covariance
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 0 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 500 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 300 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 100 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 400 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 200 ...
# <xarray.Dataset>
# Dimensions:               (lat: 100, lon: 96)
# Coordinates:
#   * lat                   (lat) float64 36.52 36.57 36.62 ... 41.37 41.42 41.47
#   * lon                   (lon) float64 -104.0 -103.9 -103.9 ... -99.07 -99.02
#     time                  <U9 '2021-4-01'
# Data variables: (12/66)
#     residual_predictions  (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     residual_uncertainty  (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     validity_flag         (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B2                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B3                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B4                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     ...                    ...
#     trend_surface         (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     me_variance           (lat, lon) float32 nan nan nan nan ... nan nan nan nan
#     predictions           (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     scaled_residuals      (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     trend_surface_rmspe   (lat, lon) float32 0.06272 0.06272 ... 0.06272 0.06272
#     rmspe                 (lat, lon) float64 nan nan nan nan ... nan nan nan nan
# Attributes:
#     timedeltas:        [0, 1]
#     num_local_values:  150

# %%
# Save multivariate predictive distribution
pd.DataFrame(dict_krige["predictive_mean"]).to_csv(
    f"../../data/intermediate/validation/{year_month_str}/mean_kriging_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)

pd.DataFrame(dict_krige["predictive_covariance_matrix"]).to_csv(
    f"../../data/intermediate/validation/{year_month_str}/covariance_kriging_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)

# %%
# Prepare validation results
df_krige = (
    ds_krige.to_dataframe().reset_index()[["lat", "lon", "predictions", "rmspe"]].dropna()
)

df_test_krige = validation.prepare_validation_results(
    df_krige,
    df_test,
    method="kriging",
    month=year_month_str,
    region=BLOCK_NAME,
)

# Compute QQ-plot quantiles
quantiles_krige = sm.ProbPlot(df_test_krige["ratio"].values)
df_quantiles_krige = pd.DataFrame(
    dict(
        sample=quantiles_krige.sample_quantiles,
        theoretical=quantiles_krige.theoretical_quantiles,
        Method="Kriging",
    )
)

# %% [markdown]
# ## Trend-only

# %%
# Prepare validation results
df_trend = (
    ds_krige.to_dataframe()
    .reset_index()[["lat", "lon", "trend_surface", "trend_surface_rmspe"]]
    .dropna()
    .rename(columns={"trend_surface": "predictions", "trend_surface_rmspe": "rmspe"})
)

df_test_trend = validation.prepare_validation_results(
    df_trend,
    df_test,
    method="Trend surface",
    month=year_month_str,
    region=BLOCK_NAME,
)

# Compute QQ-plot quantiles
quantiles_trend = sm.ProbPlot(df_test_trend["ratio"].values)
df_quantiles_trend = pd.DataFrame(
    dict(
        sample=quantiles_trend.sample_quantiles,
        theoretical=quantiles_trend.theoretical_quantiles,
        Method="Trend surface",
    )
)

# %%
# Save multivariate predictive distribution
df_test_trend["predictions"].to_csv(
    f"../../data/intermediate/validation/{year_month_str}/mean_trend_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)
pd.DataFrame(np.diag(df_test_trend["rmspe"].values ** 2)).to_csv(
    f"../../data/intermediate/validation/{year_month_str}/covariance_trend_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)

# %% [markdown]
# ## Collect results

# %%
df_validation_results = pd.concat(
    [df_test_trend, df_test_krige, df_test_cokrige], axis=0
).reset_index(drop=True)
df_validation_results.to_csv(
    f"../../data/intermediate/validation/{year_month_str}/validation_results_{BLOCK_NAME}.csv"
)
df_validation_results
# Out:
#              Method   Month Region     lat      lon      data  predictions  \
# 0     Trend surface  202104     b2  36.525 -103.775 -0.103662     0.079495
# 1     Trend surface  202104     b2  36.525 -103.725  0.456368     0.087460
# 2     Trend surface  202104     b2  36.525 -103.025  0.373465     0.211123
# 3     Trend surface  202104     b2  36.525 -101.475  0.286165     0.553083
# 4     Trend surface  202104     b2  36.525 -100.825  0.915663     0.692728
# ...             ...     ...    ...     ...      ...       ...          ...
# 1777      Cokriging  202104     b2  41.475 -101.425 -0.117198     0.281625
# 1778      Cokriging  202104     b2  41.475  -99.925  0.777075     0.612565
# 1779      Cokriging  202104     b2  41.475  -99.875  1.162170     0.606201
# 1780      Cokriging  202104     b2  41.475  -99.325  0.538670     0.545137
# 1781      Cokriging  202104     b2  41.475  -99.275  0.836137     0.532530
#
#          rmspe  difference     ratio       INT       DSS
# 0     0.382263    0.183157  0.479139  1.501509 -1.693718
# 1     0.373052   -0.368909 -0.988893  1.465328 -0.994165
# 2     0.423454   -0.162342 -0.383377  1.663305 -1.571643
# 3     0.415928    0.266917  0.641740  1.633741 -1.342658
# 4     0.407135   -0.222935 -0.547571  1.599204 -1.497387
# ...        ...         ...       ...       ...       ...
# 1777  0.429435    0.398823  0.928716  1.686795 -0.828059
# 1778  0.535656   -0.164510 -0.307119  2.104027 -1.154205
# 1779  0.527425   -0.555968 -1.054118  2.071697 -0.168331
# 1780  0.416048    0.006467  0.015543  1.634214 -1.753668
# 1781  0.450043   -0.303607 -0.674617  1.767743 -1.141717
#
# [1782 rows x 12 columns]

# %%
df_quantiles = pd.concat(
    [df_quantiles_trend, df_quantiles_krige, df_quantiles_cokrige], axis=0
).reset_index(drop=True)
df_quantiles.to_csv(
    f"../../data/intermediate/validation/{year_month_str}/validation_ratio_quantiles_{BLOCK_NAME}.csv"
)

df_quantiles
# Out:
#         sample  theoretical         Method
# 0    -2.819281    -2.932602  Trend surface
# 1    -2.780381    -2.710278  Trend surface
# 2    -2.509604    -2.572934  Trend surface
# 3    -2.136057    -2.471749  Trend surface
# 4    -1.985354    -2.390909  Trend surface
# ...        ...          ...            ...
# 1777  2.409227     2.390909      Cokriging
# 1778  2.451333     2.471749      Cokriging
# 1779  2.489772     2.572934      Cokriging
# 1780  2.505420     2.710278      Cokriging
# 1781  2.828362     2.932602      Cokriging
#
# [1782 rows x 3 columns]
