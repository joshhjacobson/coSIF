# %% [markdown]
# # Within-sample validation against withheld validation block
#
# Leave out a block of data and predict the withheld data. Models include cokriging, kriging,
# and trend-only prediction

# %%
import sys

sys.path.insert(0, "../../source")

# %%
from copy import deepcopy
import pickle
import numpy as np
import pandas as pd
import xarray as xr
import statsmodels.api as sm

import matplotlib.pyplot as plt
import seaborn as sns

import plot
import prediction
import validation

# %%
from dask.distributed import Client

# NOTE: update depending on which node is used
N_WORKERS = 84
client = Client(n_workers=N_WORKERS)
# Out:
# /home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/node.py:183: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 40223 instead
#   warnings.warn(
# 2023-06-13 13:37:28,875 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-4tcvxel1', purging
# 2023-06-13 13:37:28,875 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-gvro_7zv', purging
# 2023-06-13 13:37:28,875 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-_5ftwdud', purging
# 2023-06-13 13:37:28,875 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-hl0hieqf', purging
# 2023-06-13 13:37:28,875 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-9tmf0brz', purging
# 2023-06-13 13:37:28,876 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-uo7smfmm', purging
# 2023-06-13 13:37:28,876 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ei9hi3qy', purging
# 2023-06-13 13:37:28,876 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-fc4aru2r', purging
# 2023-06-13 13:37:28,876 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-1m7whlwd', purging
# 2023-06-13 13:37:28,876 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-wc3x5u9i', purging
# 2023-06-13 13:37:28,876 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-q6luezd_', purging
# 2023-06-13 13:37:28,876 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ppt83owf', purging
# 2023-06-13 13:37:28,876 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-k4o9b4m4', purging
# 2023-06-13 13:37:28,876 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-fl9x78bu', purging
# 2023-06-13 13:37:28,876 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ajmk88n6', purging
# 2023-06-13 13:37:28,876 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-glx_328k', purging
# 2023-06-13 13:37:28,876 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-0qth0jfi', purging
# 2023-06-13 13:37:28,876 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-3yg42wi9', purging
# 2023-06-13 13:37:28,876 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-5ys7fyzn', purging
# 2023-06-13 13:37:28,877 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-cngjb4te', purging
# 2023-06-13 13:37:28,877 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-eeetwfnf', purging
# 2023-06-13 13:37:28,877 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-1s6sdk_w', purging
# 2023-06-13 13:37:28,877 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-c3pye4kf', purging
# 2023-06-13 13:37:28,877 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-i8ncyh11', purging
# 2023-06-13 13:37:28,877 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ljw0ky8b', purging
# 2023-06-13 13:37:28,877 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-9aaqc7je', purging
# 2023-06-13 13:37:28,877 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-u23dpty6', purging
# 2023-06-13 13:37:28,877 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ahvogo_d', purging
# 2023-06-13 13:37:28,877 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-_u6t2x6u', purging
# 2023-06-13 13:37:28,877 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ywtualo8', purging
# 2023-06-13 13:37:28,877 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-mnck7cf7', purging
# 2023-06-13 13:37:28,877 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-d3uns4gz', purging
# 2023-06-13 13:37:28,877 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-oa4pkyv8', purging
# 2023-06-13 13:37:28,877 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-qwdz8yu4', purging
# 2023-06-13 13:37:28,878 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-qktfyeg3', purging
# 2023-06-13 13:37:28,878 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-wfnl8l0a', purging
# 2023-06-13 13:37:28,878 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-qmq_abag', purging
# 2023-06-13 13:37:28,878 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-7kg9p486', purging
# 2023-06-13 13:37:28,878 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-kk5_egmq', purging
# 2023-06-13 13:37:28,878 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-n4ki29g4', purging
# 2023-06-13 13:37:28,878 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-gm4vojsy', purging
# 2023-06-13 13:37:28,878 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-0qlm31cs', purging
# 2023-06-13 13:37:28,878 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-lg__or2h', purging
# 2023-06-13 13:37:28,878 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-55bvdnfp', purging
# 2023-06-13 13:37:28,878 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-mi1px0w3', purging
# 2023-06-13 13:37:28,878 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-2ki11el3', purging
# 2023-06-13 13:37:28,878 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-soprkkoc', purging
# 2023-06-13 13:37:28,878 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-qaeufyyt', purging
# 2023-06-13 13:37:28,878 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-95wrk4co', purging
# 2023-06-13 13:37:28,879 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-fechljpl', purging
# 2023-06-13 13:37:28,879 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-wmqm631o', purging
# 2023-06-13 13:37:28,879 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-adhfc5n1', purging
# 2023-06-13 13:37:28,879 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-h37_gvb8', purging
# 2023-06-13 13:37:28,879 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ttqgpat2', purging
# 2023-06-13 13:37:28,879 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-n2x0k18q', purging
# 2023-06-13 13:37:28,879 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-31lmqa7i', purging
# 2023-06-13 13:37:28,879 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-3klqdgjz', purging
# 2023-06-13 13:37:28,879 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-4s462diq', purging
# 2023-06-13 13:37:28,879 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-pu7p830d', purging
# 2023-06-13 13:37:28,879 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-r6pf041m', purging
# 2023-06-13 13:37:28,879 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-tt_u0fip', purging
# 2023-06-13 13:37:28,879 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-e2aimo3v', purging
# 2023-06-13 13:37:28,879 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ayllns0_', purging
# 2023-06-13 13:37:28,880 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-98cb4tmn', purging
# 2023-06-13 13:37:28,880 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-msgii8u_', purging
# 2023-06-13 13:37:28,880 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-8_5syd8k', purging
# 2023-06-13 13:37:28,880 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-3dyac2r8', purging
# 2023-06-13 13:37:28,880 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-fg6v8g5c', purging
# 2023-06-13 13:37:28,880 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-5ry9y9g5', purging
# 2023-06-13 13:37:28,880 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-a0z2966j', purging
# 2023-06-13 13:37:28,880 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-czt6qgvx', purging
# 2023-06-13 13:37:28,880 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ub6lwhxu', purging
# 2023-06-13 13:37:28,880 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-sx_6igyp', purging
# 2023-06-13 13:37:28,880 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-2uiizvuf', purging
# 2023-06-13 13:37:28,880 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-hahsftsz', purging
# 2023-06-13 13:37:28,880 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-k63vr_4x', purging
# 2023-06-13 13:37:28,880 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ir1ypywl', purging
# 2023-06-13 13:37:28,881 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-hdoa21wg', purging
# 2023-06-13 13:37:28,881 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-g44n22ud', purging
# 2023-06-13 13:37:28,881 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-qoy61y1t', purging
# 2023-06-13 13:37:28,881 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-fld2fiyi', purging
# 2023-06-13 13:37:28,881 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-qy43jh8g', purging
# 2023-06-13 13:37:28,881 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-c_yepjv9', purging
# 2023-06-13 13:37:28,881 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-lfqhe75q', purging

# %%
# number of nearest observations used in point predictions
NUM_LOCAL_VALUES = 150

# data selection
YEAR = 2021
MONTH = 7
# XCO2 months ahead of SIF
OFFSET = 1

year_month_str = f"{YEAR}0{MONTH}" if MONTH < 10 else f"{YEAR}{MONTH}"

# %%
month_xco2 = MONTH + OFFSET
date_sif = f"{YEAR}-{MONTH}-01"
date_xco2 = f"{YEAR}-{month_xco2}-01"

with xr.open_dataset(
    "../../data/intermediate/OCO2_005deg_monthly_north_america_with_basis.nc4"
) as ds:
    basis_vars = [x for x in list(ds.keys()) if x.startswith("B")]
    ds_sif = ds[["sif", "sif_var"] + basis_vars].sel(time=f"{YEAR}-{MONTH}").squeeze()

# %%
BLOCK_NAME = "b2"
block_conditions = (
    (ds_sif["lon"] > -104)
    & (ds_sif["lon"] < -99)
    & (ds_sif["lat"] > 36.5)
    & (ds_sif["lat"] < 41.5)
)
ds_test = ds_sif.where(block_conditions)

plot.plot_da(ds_test["sif"])

# %%
df_test = (
    ds_test.to_dataframe()
    .dropna(subset="sif")
    .reset_index()[["lat", "lon", "sif", "sif_var"] + basis_vars]
    .rename(columns={"sif": "data", "sif_var": "me_variance"})
)
df_me_variance = df_test.loc[:, ["lat", "lon", "me_variance"]]
df_test = df_test.drop(columns="me_variance")
ds_covariates = (
    df_test.set_index(["lat", "lon"]).to_xarray().drop_vars(["data", "B1", "B10", "B20"])
)
df_test = df_test.loc[:, ["lat", "lon", "data"]]
pcoords = df_test.loc[:, ["lat", "lon"]]
df_test.to_csv(f"../../data/intermediate/validation/{year_month_str}/df_test_{BLOCK_NAME}.csv")
df_test
# Out:
#         lat      lon      data
# 0    36.525 -103.225  1.536174
# 1    36.525 -103.175  0.196737
# 2    36.525 -102.925  0.893672
# 3    36.525 -101.625  0.365366
# 4    36.525 -101.575  0.713269
# ..      ...      ...       ...
# 707  41.475 -103.275  1.403427
# 708  41.475 -102.925  0.385335
# 709  41.475 -101.725  1.254574
# 710  41.475 -100.175  1.169107
# 711  41.475  -99.825  2.222317
#
# [712 rows x 3 columns]

# %%
ds_covariates
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 100, lon: 100)
# Coordinates:
#   * lat      (lat) float64 36.52 36.57 36.62 36.67 ... 41.32 41.37 41.42 41.47
#   * lon      (lon) float64 -104.0 -103.9 -103.9 -103.8 ... -99.12 -99.07 -99.02
# Data variables: (12/57)
#     B2       (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B3       (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B4       (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B5       (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B6       (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B7       (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     ...       ...
#     B55      (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B56      (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B57      (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B58      (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B59      (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B60      (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan

# %%
sns.histplot(df_test["data"].values)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ## Cokriging

# %%
# Load multifield and model objects
with open(f"../../data/intermediate/models/{year_month_str}/fields.pickle", "rb") as f:
    mf = pickle.load(f)

with open(f"../../data/intermediate/models/{year_month_str}/bivariate_model.pickle", "rb") as f:
    bivariate_matern = pickle.load(f)

# %%
# Make validation predictions
cokrige = prediction.Predictor(bivariate_matern, mf)
dict_cokrige = cokrige.validation_prediction(
    0,
    pcoords,
    df_me_variance,
    ds_covariates,
    num_local_values=NUM_LOCAL_VALUES,
)
ds_cokrige = dict_cokrige["ds"]
ds_cokrige
# Out:
# INFO | root:_compute_prediction_covariance_matrix:475 | Running predictive covariance
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 0 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 400 ...
# 2023-06-13 13:40:51,821 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.24 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:40:51,876 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.27 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:40:52,009 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.31 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:40:52,077 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.34 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:40:52,181 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.38 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:40:52,284 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.43 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:40:52,385 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.49 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:40:52,500 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.54 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:40:52,589 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.56 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:40:52,607 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.22 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:40:52,676 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.58 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:40:52,701 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.26 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:40:52,811 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.33 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:40:52,819 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.63 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:40:52,877 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.64 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:40:52,896 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.39 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:40:52,992 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.45 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:40:53,090 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.48 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:40:53,186 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.53 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:40:53,290 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.59 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:40:53,429 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.65 GiB -- Worker memory limit: 5.99 GiB
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 500 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 200 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 600 ...
# 2023-06-13 13:42:14,971 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.22 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:15,075 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.32 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:15,175 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.39 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:15,265 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.46 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:15,371 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.53 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:15,495 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.62 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:16,626 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.20 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:16,691 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.31 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:16,691 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.31 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:16,724 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.29 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:16,793 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.40 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:16,809 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.37 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:16,893 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.49 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:16,933 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.48 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:16,981 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.56 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:17,040 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.59 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:17,089 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.64 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:17,117 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.65 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:17,559 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.33 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:17,590 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.35 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:17,688 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.44 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:17,728 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.23 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:17,785 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.52 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:17,821 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.30 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:17,890 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.63 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:17,893 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.25 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:17,946 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.40 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:17,999 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.31 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:18,030 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.47 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:18,102 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.40 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:18,121 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.55 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:18,197 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.50 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:18,225 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.62 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:18,288 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.58 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:19,435 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.22 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:19,487 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.27 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:19,581 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.20 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:19,605 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.37 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:19,680 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.29 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:19,688 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.43 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:19,729 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.22 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:19,790 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.36 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:19,802 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.50 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:19,817 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.29 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:19,889 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.43 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:19,911 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.59 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:19,918 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.36 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:19,969 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.20 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:19,990 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.65 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,007 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.52 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,023 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.47 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,066 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.22 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,082 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.58 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,141 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.55 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,168 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.25 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,183 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.66 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,220 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.59 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,267 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.29 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,369 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.31 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,502 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.35 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,565 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.36 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,668 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.39 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,760 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.21 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,767 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.41 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,811 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.26 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,860 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.27 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,866 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.43 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,880 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.31 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,979 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.36 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:20,981 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.40 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,001 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.46 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,063 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.45 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,066 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.46 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,113 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.51 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,145 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.53 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,181 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.48 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,206 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.58 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,248 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.62 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,275 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.51 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,288 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.64 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,373 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.53 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,478 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.55 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,571 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.58 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,666 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.63 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,689 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.21 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,767 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.67 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,801 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.29 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,867 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.69 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,893 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.37 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,911 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.22 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,969 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.73 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,993 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.44 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:21,994 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.29 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,063 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.25 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,069 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.75 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,078 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.49 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,118 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.36 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,168 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.78 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,175 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.30 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,193 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.56 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,205 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.40 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,257 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.35 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,282 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.79 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,285 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.64 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,295 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.45 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,350 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.40 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,400 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.53 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,452 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.48 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,515 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.62 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,546 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.58 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,647 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.66 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,726 - distributed.worker_memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 4.81 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,726 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.81 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:42:22,729 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.83 GiB -- Worker memory limit: 5.99 GiB
# ...
# 2023-06-13 13:43:11,084 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.53 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:11,143 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.38 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:11,147 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.44 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:11,159 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.42 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:11,162 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.57 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:11,218 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.45 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:11,232 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.55 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:11,274 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.31 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:11,275 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.31 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:11,331 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.65 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:11,343 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.63 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:11,344 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.63 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:11,395 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.61 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:11,410 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.41 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:11,435 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.63 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:11,484 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.49 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:11,600 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.56 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:11,673 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.63 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:14,433 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.30 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:14,493 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.37 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:14,589 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.48 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:14,697 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.61 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:15,994 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.23 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:16,076 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.31 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:16,179 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.42 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:16,288 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.51 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:16,362 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.62 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:16,687 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.27 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:16,705 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.28 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:16,825 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.41 GiB -- Worker memory limit: 5.99 GiB
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 700 ...
# 2023-06-13 13:43:16,920 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.48 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:17,005 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.51 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:17,174 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.57 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:17,218 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.60 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:17,324 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.68 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:17,432 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.74 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:17,674 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.19 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:17,798 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.33 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:17,861 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.41 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:17,959 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.53 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:43:18,059 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.65 GiB -- Worker memory limit: 5.99 GiB
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 100 ...
# <xarray.Dataset>
# Dimensions:               (lat: 100, lon: 100)
# Coordinates:
#   * lat                   (lat) float64 36.52 36.57 36.62 ... 41.37 41.42 41.47
#   * lon                   (lon) float64 -104.0 -103.9 -103.9 ... -99.07 -99.02
#     time                  <U9 '2021-7-01'
# Data variables: (12/66)
#     residual_predictions  (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     residual_uncertainty  (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     validity_flag         (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B2                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B3                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B4                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     ...                    ...
#     trend_surface         (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     me_variance           (lat, lon) float32 nan nan nan nan ... nan nan nan nan
#     predictions           (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     scaled_residuals      (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     trend_surface_rmspe   (lat, lon) float32 0.247 0.247 0.247 ... 0.247 0.247
#     rmspe                 (lat, lon) float64 nan nan nan nan ... nan nan nan nan
# Attributes:
#     timedeltas:        [0, 1]
#     num_local_values:  150

# %%
# Save multivariate predictive distribution
pd.DataFrame(dict_cokrige["predictive_mean"]).to_csv(
    f"../../data/intermediate/validation/{year_month_str}/mean_cokriging_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)

pd.DataFrame(dict_cokrige["predictive_covariance_matrix"]).to_csv(
    f"../../data/intermediate/validation/{year_month_str}/covariance_cokriging_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)

# %%
# Prepare validation results
df_cokrige = (
    ds_cokrige.to_dataframe().reset_index()[["lat", "lon", "predictions", "rmspe"]].dropna()
)

df_test_cokrige = validation.prepare_validation_results(
    df_cokrige,
    df_test,
    method="cokriging",
    month=year_month_str,
    region=BLOCK_NAME,
)

# Compute QQ-plot quantiles
quantiles_cokrige = sm.ProbPlot(df_test_cokrige["ratio"].values)
df_quantiles_cokrige = pd.DataFrame(
    dict(
        sample=quantiles_cokrige.sample_quantiles,
        theoretical=quantiles_cokrige.theoretical_quantiles,
        Method="Cokriging",
    )
)

# %% [markdown]
# ## Kriging

# %%
client.close()
# Out:
# 2023-06-13 13:44:19,026 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37440 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,046 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37418 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,340 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37014 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,536 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37346 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,699 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37054 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,732 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37068 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,749 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37546 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,770 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37260 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,781 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37116 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,792 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37560 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,793 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37296 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,793 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37574 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,797 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37108 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,797 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37150 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,798 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37626 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,799 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:36936 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,799 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37722 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,802 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37516 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,809 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37730 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,861 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37268 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,892 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37478 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:19,934 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37668 remote=tcp://127.0.0.1:37147>: Stream is closed
# 2023-06-13 13:44:20,014 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37586 remote=tcp://127.0.0.1:37147>: Stream is closed

# %%
client = Client(n_workers=N_WORKERS)
# Out:
# /home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/node.py:183: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 43011 instead
#   warnings.warn(

# %%
# Isolate SIF field only
mf_univariate = deepcopy(mf)
mf_univariate.fields = np.array([mf_univariate.fields[0]])
mf_univariate.n_procs = 1

# Load univariate model
with open(
    f"../../data/intermediate/models/{year_month_str}/univariate_model.pickle", "rb"
) as f:
    univariate_matern = pickle.load(f)

# %%
# Make validation predictions
krige = prediction.Predictor(univariate_matern, mf_univariate)
dict_krige = krige.validation_prediction(
    0,
    pcoords,
    df_me_variance,
    ds_covariates,
    num_local_values=NUM_LOCAL_VALUES,
)
ds_krige = dict_krige["ds"]
ds_krige
# Out:
# INFO | root:_compute_prediction_covariance_matrix:475 | Running predictive covariance
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 400 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 0 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 500 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 200 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 600 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 300 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 100 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 700 ...
# <xarray.Dataset>
# Dimensions:               (lat: 100, lon: 100)
# Coordinates:
#   * lat                   (lat) float64 36.52 36.57 36.62 ... 41.37 41.42 41.47
#   * lon                   (lon) float64 -104.0 -103.9 -103.9 ... -99.07 -99.02
#     time                  <U9 '2021-7-01'
# Data variables: (12/66)
#     residual_predictions  (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     residual_uncertainty  (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     validity_flag         (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B2                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B3                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B4                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     ...                    ...
#     trend_surface         (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     me_variance           (lat, lon) float32 nan nan nan nan ... nan nan nan nan
#     predictions           (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     scaled_residuals      (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     trend_surface_rmspe   (lat, lon) float32 0.247 0.247 0.247 ... 0.247 0.247
#     rmspe                 (lat, lon) float64 nan nan nan nan ... nan nan nan nan
# Attributes:
#     timedeltas:        [0, 1]
#     num_local_values:  150

# %%
# Save multivariate predictive distribution
pd.DataFrame(dict_krige["predictive_mean"]).to_csv(
    f"../../data/intermediate/validation/{year_month_str}/mean_kriging_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)

pd.DataFrame(dict_krige["predictive_covariance_matrix"]).to_csv(
    f"../../data/intermediate/validation/{year_month_str}/covariance_kriging_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)

# %%
# Prepare validation results
df_krige = (
    ds_krige.to_dataframe().reset_index()[["lat", "lon", "predictions", "rmspe"]].dropna()
)

df_test_krige = validation.prepare_validation_results(
    df_krige,
    df_test,
    method="kriging",
    month=year_month_str,
    region=BLOCK_NAME,
)

# Compute QQ-plot quantiles
quantiles_krige = sm.ProbPlot(df_test_krige["ratio"].values)
df_quantiles_krige = pd.DataFrame(
    dict(
        sample=quantiles_krige.sample_quantiles,
        theoretical=quantiles_krige.theoretical_quantiles,
        Method="Kriging",
    )
)

# %% [markdown]
# ## Trend-only

# %%
# Prepare validation results
df_trend = (
    ds_krige.to_dataframe()
    .reset_index()[["lat", "lon", "trend_surface", "trend_surface_rmspe"]]
    .dropna()
    .rename(columns={"trend_surface": "predictions", "trend_surface_rmspe": "rmspe"})
)

df_test_trend = validation.prepare_validation_results(
    df_trend,
    df_test,
    method="Trend surface",
    month=year_month_str,
    region=BLOCK_NAME,
)

# Compute QQ-plot quantiles
quantiles_trend = sm.ProbPlot(df_test_trend["ratio"].values)
df_quantiles_trend = pd.DataFrame(
    dict(
        sample=quantiles_trend.sample_quantiles,
        theoretical=quantiles_trend.theoretical_quantiles,
        Method="Trend surface",
    )
)

# %%
# Save multivariate predictive distribution
df_test_trend["predictions"].to_csv(
    f"../../data/intermediate/validation/{year_month_str}/mean_trend_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)
pd.DataFrame(np.diag(df_test_trend["rmspe"].values ** 2)).to_csv(
    f"../../data/intermediate/validation/{year_month_str}/covariance_trend_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)

# %% [markdown]
# ## Collect results

# %%
df_validation_results = pd.concat(
    [df_test_trend, df_test_krige, df_test_cokrige], axis=0
).reset_index(drop=True)
df_validation_results.to_csv(
    f"../../data/intermediate/validation/{year_month_str}/validation_results_{BLOCK_NAME}.csv"
)
df_validation_results
# Out:
#              Method   Month Region     lat      lon      data  predictions  \
# 0     Trend surface  202107     b2  36.525 -103.225  1.536174     0.831319
# 1     Trend surface  202107     b2  36.525 -103.175  0.196737     0.835066
# 2     Trend surface  202107     b2  36.525 -102.925  0.893672     0.852733
# 3     Trend surface  202107     b2  36.525 -101.625  0.365366     0.909853
# 4     Trend surface  202107     b2  36.525 -101.575  0.713269     0.910987
# ...             ...     ...    ...     ...      ...       ...          ...
# 2131      Cokriging  202107     b2  41.475 -103.275  1.403427     0.718087
# 2132      Cokriging  202107     b2  41.475 -102.925  0.385335     0.814823
# 2133      Cokriging  202107     b2  41.475 -101.725  1.254574     0.827181
# 2134      Cokriging  202107     b2  41.475 -100.175  1.169107     1.135142
# 2135      Cokriging  202107     b2  41.475  -99.825  2.222317     1.586542
#
#          rmspe  difference     ratio       INT       DSS
# 0     0.483075   -0.704854 -1.459100  1.896847  0.673806
# 1     0.495226    0.638329  1.288966  1.944559  0.255951
# 2     0.498633   -0.040939 -0.082103  1.957939 -1.385029
# 3     0.472423    0.544487  1.152542  1.855022 -0.171408
# 4     0.477345    0.197718  0.414203  1.874349 -1.307466
# ...        ...         ...       ...       ...       ...
# 2131  0.465636   -0.685340 -1.471838  1.828371  0.637603
# 2132  0.479922    0.429488  0.894913  1.884467 -0.667395
# 2133  0.481533   -0.427393 -0.887567  1.890793 -0.673786
# 2134  0.442437   -0.033965 -0.076768  1.737279 -1.625021
# 2135  0.505530   -0.635775 -1.257640  1.985022  0.217365
#
# [2136 rows x 12 columns]

# %%
df_quantiles = pd.concat(
    [df_quantiles_trend, df_quantiles_krige, df_quantiles_cokrige], axis=0
).reset_index(drop=True)
df_quantiles.to_csv(
    f"../../data/intermediate/validation/{year_month_str}/validation_ratio_quantiles_{BLOCK_NAME}.csv"
)

df_quantiles
# Out:
#         sample  theoretical         Method
# 0    -3.792268    -2.988332  Trend surface
# 1    -3.728694    -2.769740  Trend surface
# 2    -3.674473    -2.634943  Trend surface
# 3    -3.562361    -2.535765  Trend surface
# 4    -3.320818    -2.456616  Trend surface
# ...        ...          ...            ...
# 2131  3.287464     2.456616      Cokriging
# 2132  3.381865     2.535765      Cokriging
# 2133  3.859985     2.634943      Cokriging
# 2134  4.217667     2.769740      Cokriging
# 2135  4.940287     2.988332      Cokriging
#
# [2136 rows x 3 columns]
