# %% [markdown]
# # Missing Block Cross Validation
#
# Leave out a block of data and predict the withheld data. Models include cokriging, kriging,
# and trend-only prediction

# %%
import sys

sys.path.insert(0, "../../source")

# %%
from copy import deepcopy
import pickle
import numpy as np
import pandas as pd
import xarray as xr
import statsmodels.api as sm

import matplotlib.pyplot as plt
import seaborn as sns
from cmcrameri import cm

import plot
import prediction
import validation

# %%
from dask.distributed import Client

# NOTE: update depending on which node is used
N_WORKERS = 84
client = Client(n_workers=N_WORKERS)
# Out:
# /home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/node.py:183: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 46053 instead
#   warnings.warn(
# 2023-05-04 14:21:27,746 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-wvohmxaq', purging
# 2023-05-04 14:21:27,747 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-dxk9k8zx', purging
# 2023-05-04 14:21:27,747 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-4d7lp4u7', purging
# 2023-05-04 14:21:27,747 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-_l7tv_q8', purging
# 2023-05-04 14:21:27,747 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-uip7gdi_', purging
# 2023-05-04 14:21:27,747 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-gklap04_', purging
# 2023-05-04 14:21:27,747 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-y5g4mo8n', purging
# 2023-05-04 14:21:27,747 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ronmnrat', purging
# 2023-05-04 14:21:27,747 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-68fc4r5_', purging
# 2023-05-04 14:21:27,747 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-h_tfabrf', purging
# 2023-05-04 14:21:27,747 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-fz5mbtje', purging
# 2023-05-04 14:21:27,747 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-f6uthekt', purging
# 2023-05-04 14:21:27,747 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-yg_y68o7', purging
# 2023-05-04 14:21:27,747 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-8sthrbx2', purging
# 2023-05-04 14:21:27,747 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-t3ylon42', purging
# 2023-05-04 14:21:27,748 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-djrl011j', purging
# 2023-05-04 14:21:27,748 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-pa962d6l', purging
# 2023-05-04 14:21:27,748 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-i1a4n0bs', purging
# 2023-05-04 14:21:27,748 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-cwm2mv98', purging
# 2023-05-04 14:21:27,748 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-bzxsj8hc', purging
# 2023-05-04 14:21:27,748 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-iqcnl6m4', purging
# 2023-05-04 14:21:27,748 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-pg1kf65d', purging
# 2023-05-04 14:21:27,748 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-x__syi89', purging
# 2023-05-04 14:21:27,748 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-07lr585t', purging
# 2023-05-04 14:21:27,748 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-_vholph6', purging
# 2023-05-04 14:21:27,748 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ne_9e58n', purging
# 2023-05-04 14:21:27,748 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-pn5akkd9', purging
# 2023-05-04 14:21:27,748 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-imk68dh2', purging
# 2023-05-04 14:21:27,748 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-t8ro3p7m', purging
# 2023-05-04 14:21:27,749 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-rg2zkqpu', purging
# 2023-05-04 14:21:27,749 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-nzllv476', purging
# 2023-05-04 14:21:27,749 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-s7z1iv44', purging
# 2023-05-04 14:21:27,749 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-cgz7d3d_', purging
# 2023-05-04 14:21:27,749 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-85ysmk73', purging
# 2023-05-04 14:21:27,749 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-_t8wn7d0', purging
# 2023-05-04 14:21:27,749 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-w_7d88jv', purging
# 2023-05-04 14:21:27,749 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-1g2eyqxf', purging
# 2023-05-04 14:21:27,749 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-r8lwomz0', purging
# 2023-05-04 14:21:27,749 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-_u58aafy', purging
# 2023-05-04 14:21:27,749 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-l2e2f5wx', purging
# 2023-05-04 14:21:27,749 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-a3gc_5j2', purging
# 2023-05-04 14:21:27,749 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ihx6tz26', purging
# 2023-05-04 14:21:27,749 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-37ccrk2_', purging
# 2023-05-04 14:21:27,749 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ioc69aww', purging
# 2023-05-04 14:21:27,750 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-fkib80gj', purging
# 2023-05-04 14:21:27,750 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ddrfegj_', purging
# 2023-05-04 14:21:27,750 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-wmg0uk7u', purging
# 2023-05-04 14:21:27,750 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-pdda_kh5', purging
# 2023-05-04 14:21:27,750 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-rasv5ama', purging
# 2023-05-04 14:21:27,750 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-7rj8310x', purging
# 2023-05-04 14:21:27,750 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-_ro2t483', purging
# 2023-05-04 14:21:27,750 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-y_65v6v3', purging
# 2023-05-04 14:21:27,750 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ipzmn8em', purging
# 2023-05-04 14:21:27,750 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-u2yrqyrt', purging
# 2023-05-04 14:21:27,750 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-9a1md4ht', purging
# 2023-05-04 14:21:27,750 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-42jjf9c2', purging
# 2023-05-04 14:21:27,750 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-y89tuxpy', purging
# 2023-05-04 14:21:27,750 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-8qa6uoms', purging
# 2023-05-04 14:21:27,751 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-_nscydjo', purging
# 2023-05-04 14:21:27,751 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-z15daaud', purging
# 2023-05-04 14:21:27,751 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-n9mddkig', purging
# 2023-05-04 14:21:27,751 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-hrv0g8o0', purging
# 2023-05-04 14:21:27,751 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ph8l_de1', purging
# 2023-05-04 14:21:27,751 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-2ybsjdiv', purging
# 2023-05-04 14:21:27,751 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-b_8m9cdo', purging
# 2023-05-04 14:21:27,751 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-28e1ns_7', purging
# 2023-05-04 14:21:27,751 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-533_f1e2', purging
# 2023-05-04 14:21:27,751 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-1jf2r617', purging
# 2023-05-04 14:21:27,751 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-4xtv0oqh', purging
# 2023-05-04 14:21:27,751 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-wtda6z2v', purging
# 2023-05-04 14:21:27,751 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-uitjn6ji', purging
# 2023-05-04 14:21:27,751 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-__xw00yk', purging
# 2023-05-04 14:21:27,752 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-cvaa7ur_', purging
# 2023-05-04 14:21:27,752 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-zd3c0z07', purging
# 2023-05-04 14:21:27,752 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-0eky1vl9', purging
# 2023-05-04 14:21:27,752 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-bo1e1ejv', purging
# 2023-05-04 14:21:27,752 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-6w8rgkpo', purging
# 2023-05-04 14:21:27,752 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-i63kbo75', purging
# 2023-05-04 14:21:27,752 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ztmtc7ex', purging
# 2023-05-04 14:21:27,752 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-puus_y6l', purging
# 2023-05-04 14:21:27,752 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-sg783e43', purging
# 2023-05-04 14:21:27,752 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-fm9uj5ts', purging
# 2023-05-04 14:21:27,752 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-q3j6gjvq', purging
# 2023-05-04 14:21:27,752 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-i3n91ue5', purging

# %%
# number of nearest observations used in point predictions
NUM_LOCAL_VALUES = 150

# data selection
YEAR = 2021
MONTH = 10
# XCO2 months ahead of SIF
OFFSET = 1

year_month_str = f"{YEAR}0{MONTH}" if MONTH < 10 else f"{YEAR}{MONTH}"

# %%
month_xco2 = MONTH + OFFSET
date_sif = f"{YEAR}-{MONTH}-01"
date_xco2 = f"{YEAR}-{month_xco2}-01"

with xr.open_dataset(
    "../../data/production/OCO2_005deg_monthly_north_america_with_basis.nc4"
) as ds:
    basis_vars = [x for x in list(ds.keys()) if x.startswith("B")]
    ds_sif = ds[["sif", "sif_var"] + basis_vars].sel(time=f"{YEAR}-{MONTH}").squeeze()

# %%
BLOCK_NAME = "b2"
block_conditions = (
    (ds_sif["lon"] > -104)
    & (ds_sif["lon"] < -99)
    & (ds_sif["lat"] > 36.5)
    & (ds_sif["lat"] < 41.5)
)
ds_test = ds_sif.where(block_conditions)

plot.plot_da(ds_test["sif"])

# %%
df_test = (
    ds_test.to_dataframe()
    .dropna(subset="sif")
    .reset_index()[["lat", "lon", "sif", "sif_var"] + basis_vars]
    .rename(columns={"sif": "data", "sif_var": "measurement_error"})
)
df_measurement_error = df_test.loc[:, ["lat", "lon", "measurement_error"]]
df_test = df_test.drop(columns="measurement_error")
ds_covariates = (
    df_test.set_index(["lat", "lon"]).to_xarray().drop_vars(["data", "B1", "B10", "B20"])
)
df_test = df_test.loc[:, ["lat", "lon", "data"]]
pcoords = df_test.loc[:, ["lat", "lon"]]
df_test.to_csv(f"../../data/production/validation/{year_month_str}/df_test_{BLOCK_NAME}.csv")
df_test
# Out:
#         lat      lon      data
# 0    36.525 -103.625 -0.117012
# 1    36.525 -103.575  0.155045
# 2    36.525 -101.875  0.422391
# 3    36.525 -101.425  0.377359
# 4    36.525 -101.375  0.052247
# ..      ...      ...       ...
# 703  41.425 -101.375  0.418129
# 704  41.475 -102.975 -0.184186
# 705  41.475 -102.925 -0.059710
# 706  41.475 -101.425  0.112492
# 707  41.475 -101.375  0.249514
#
# [708 rows x 3 columns]

# %%
ds_covariates
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 100, lon: 89)
# Coordinates:
#   * lat      (lat) float64 36.52 36.57 36.62 36.67 ... 41.32 41.37 41.42 41.47
#   * lon      (lon) float64 -104.0 -103.9 -103.9 -103.8 ... -99.12 -99.07 -99.02
# Data variables: (12/57)
#     B2       (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B3       (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B4       (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B5       (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B6       (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B7       (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     ...       ...
#     B55      (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B56      (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B57      (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B58      (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B59      (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B60      (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan

# %%
sns.histplot(df_test["data"].values)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ## Cokriging

# %%
# Load multifield and model objects
with open(f"../../data/production/models/{year_month_str}/fields.pickle", "rb") as f:
    mf = pickle.load(f)

with open(f"../../data/production/models/{year_month_str}/model.pickle", "rb") as f:
    bivariate_matern = pickle.load(f)

# %%
# Make validation predictions
cokrige = prediction.Predictor(bivariate_matern, mf)
dict_cokrige = cokrige.cross_validation(
    0,
    pcoords,
    df_measurement_error,
    ds_covariates,
    num_local_values=NUM_LOCAL_VALUES,
)
ds_cokrige = dict_cokrige["ds"]
ds_cokrige
# Out:
# INFO | root:_compute_prediction_covariance_matrix:518 | Running predictive covariance
# INFO | root:_compute_predictive_covariance_element:574 | Status: s = 0 ...
# INFO | root:_compute_predictive_covariance_element:574 | Status: s = 600 ...
# INFO | root:_compute_predictive_covariance_element:574 | Status: s = 500 ...
# INFO | root:_compute_predictive_covariance_element:574 | Status: s = 400 ...
# INFO | root:_compute_predictive_covariance_element:574 | Status: s = 300 ...
# INFO | root:_compute_predictive_covariance_element:574 | Status: s = 200 ...
# 2023-05-04 14:26:08,653 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.21 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:08,760 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.25 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:08,853 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.30 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:08,980 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.39 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:09,065 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.45 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:09,155 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.48 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:09,274 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.56 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:09,360 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.61 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:09,452 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.66 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:11,261 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.27 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:11,370 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.32 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:11,468 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.36 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:11,539 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.24 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:11,565 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.41 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:11,575 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.27 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:11,656 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.47 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:11,685 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.32 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:11,763 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.54 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:11,770 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.37 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:11,849 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.58 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:11,872 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.42 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:11,975 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.27 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,034 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.52 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,100 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.56 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,100 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.26 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,109 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.33 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,163 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.37 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,169 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.62 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,196 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.31 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,198 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.21 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,260 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.42 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,302 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.26 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,313 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.37 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,372 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.48 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,374 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.29 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,417 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.44 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,517 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.50 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,541 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.38 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,573 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.39 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,591 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.63 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,591 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.63 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,593 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.56 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,666 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.68 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,684 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.45 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,695 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.62 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,777 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.50 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,791 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.68 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,881 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.20 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,887 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.57 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,978 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.64 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:12,998 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.27 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,029 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.27 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,072 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.29 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,089 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.32 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,177 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.35 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,180 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.36 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,207 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.24 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,286 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.42 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,292 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.42 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,307 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.31 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,393 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.48 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,423 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.48 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,467 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.43 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,482 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.52 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,485 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.52 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,486 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.27 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,503 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.27 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,505 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.46 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,576 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.57 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,602 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.33 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,603 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.51 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,612 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.59 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,676 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.36 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,677 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.62 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,696 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.57 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,697 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.64 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,783 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.41 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,786 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.67 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,814 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.64 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,875 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.46 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:13,977 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.50 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,006 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.25 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,009 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.24 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,080 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.54 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,090 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.28 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,163 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.33 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,163 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.33 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,175 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.59 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,188 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.26 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,201 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.34 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,252 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.38 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,279 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.30 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,289 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.38 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,328 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.68 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,334 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.41 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,371 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.36 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,435 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.47 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,438 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.46 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,512 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.49 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,534 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.51 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,553 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.45 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,580 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.47 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,587 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.25 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,588 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.25 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,592 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.55 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,634 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.55 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,665 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.50 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,678 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.28 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,687 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.59 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,737 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.61 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,771 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.56 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,771 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.33 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,789 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.65 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,850 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.67 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,869 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.59 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:14,874 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.39 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:15,094 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.48 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:15,096 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.48 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:15,170 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.51 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:15,278 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.56 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:15,343 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.23 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:15,399 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.61 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:15,415 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.27 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:15,451 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.23 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:15,487 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.30 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:15,508 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.68 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:15,564 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.29 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:15,582 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.35 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:15,648 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.33 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:15,678 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.23 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:15,735 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.40 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:15,735 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.24 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:15,768 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.27 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:15,773 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.39 GiB -- Worker memory limit: 5.99 GiB
# ...
# 2023-05-04 14:26:16,258 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.67 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:16,296 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.54 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:16,350 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.60 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:16,355 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.59 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:16,542 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.68 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:16,551 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.68 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:16,555 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.28 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:16,569 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.29 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:16,665 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.34 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:16,796 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.39 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:16,837 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.28 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:16,879 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.30 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:16,879 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.46 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:16,940 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.34 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:16,941 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.34 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:16,952 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.34 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:16,956 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.34 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:16,963 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.35 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:17,136 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.42 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:17,151 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.48 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:17,174 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.44 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:17,229 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.52 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:17,318 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.59 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:17,367 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.47 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:17,418 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.60 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:17,423 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.66 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:17,492 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.65 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:17,710 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.55 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:17,714 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.52 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:17,740 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.59 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:17,812 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.63 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:18,130 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.50 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:18,475 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.55 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:18,497 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.57 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:18,571 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.89 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:18,573 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.67 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:18,586 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.68 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:18,603 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.89 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:18,790 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.39 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:19,188 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.89 GiB -- Worker memory limit: 5.99 GiB
# 2023-05-04 14:26:19,704 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.55 GiB -- Worker memory limit: 5.99 GiB
# INFO | root:_compute_predictive_covariance_element:574 | Status: s = 100 ...
# INFO | root:_compute_predictive_covariance_element:574 | Status: s = 700 ...
# <xarray.Dataset>
# Dimensions:               (lat: 100, lon: 89)
# Coordinates:
#   * lat                   (lat) float64 36.52 36.57 36.62 ... 41.37 41.42 41.47
#   * lon                   (lon) float64 -104.0 -103.9 -103.9 ... -99.07 -99.02
#     time                  <U10 '2021-10-01'
# Data variables: (12/66)
#     residual_predictions  (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     prediction_error      (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     validity_flag         (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B2                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B3                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B4                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     ...                    ...
#     trend_surface         (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     measurement_error     (lat, lon) float32 nan nan nan nan ... nan nan nan nan
#     predictions           (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     mspe                  (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     scaled_residuals      (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     trend_surface_mspe    (lat, lon) float64 0.0009026 0.0009026 ... 0.0009026
# Attributes:
#     timedeltas:        [0, 1]
#     num_local_values:  150

# %%
# Save multivariate predictive distribution
pd.DataFrame(dict_cokrige["predictive_mean"]).to_csv(
    f"../../data/production/validation/{year_month_str}/mean_cokriging_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)

pd.DataFrame(dict_cokrige["predictive_covariance_matrix"]).to_csv(
    f"../../data/production/validation/{year_month_str}/covariance_cokriging_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)

# %%
# Prepare validation results
df_cokrige = (
    ds_cokrige.to_dataframe().reset_index()[["lat", "lon", "predictions", "mspe"]].dropna()
)

df_test_cokrige = validation.prepare_validation_results(
    df_cokrige,
    df_test,
    method="cokriging",
    month=year_month_str,
    region=BLOCK_NAME,
)

# Compute QQ-plot quantiles
quantiles_cokrige = sm.ProbPlot(df_test_cokrige["ratio"].values)
df_quantiles_cokrige = pd.DataFrame(
    dict(
        sample=quantiles_cokrige.sample_quantiles,
        theoretical=quantiles_cokrige.theoretical_quantiles,
        Method="Cokriging",
    )
)

# %% [markdown]
# ## Kriging

# %%
client.close()
# Out:
# 2023-05-04 14:27:17,020 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:51678 remote=tcp://127.0.0.1:35045>: Stream is closed
# 2023-05-04 14:27:17,043 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:51770 remote=tcp://127.0.0.1:35045>: Stream is closed
# 2023-05-04 14:27:17,052 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:51960 remote=tcp://127.0.0.1:35045>: Stream is closed
# 2023-05-04 14:27:17,057 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:51922 remote=tcp://127.0.0.1:35045>: Stream is closed
# 2023-05-04 14:27:17,058 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:51738 remote=tcp://127.0.0.1:35045>: Stream is closed
# 2023-05-04 14:27:17,059 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:51650 remote=tcp://127.0.0.1:35045>: Stream is closed
# 2023-05-04 14:27:17,059 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:52024 remote=tcp://127.0.0.1:35045>: Stream is closed
# 2023-05-04 14:27:17,060 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:51858 remote=tcp://127.0.0.1:35045>: Stream is closed
# 2023-05-04 14:27:17,060 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:51436 remote=tcp://127.0.0.1:35045>: Stream is closed
# 2023-05-04 14:27:17,060 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:51462 remote=tcp://127.0.0.1:35045>: Stream is closed
# 2023-05-04 14:27:17,061 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:51700 remote=tcp://127.0.0.1:35045>: Stream is closed
# 2023-05-04 14:27:17,242 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:51978 remote=tcp://127.0.0.1:35045>: Stream is closed
# 2023-05-04 14:27:17,333 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:51784 remote=tcp://127.0.0.1:35045>: Stream is closed
# 2023-05-04 14:27:17,333 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:51614 remote=tcp://127.0.0.1:35045>: Stream is closed
# 2023-05-04 14:27:17,334 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:52004 remote=tcp://127.0.0.1:35045>: Stream is closed
# 2023-05-04 14:27:17,440 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:51660 remote=tcp://127.0.0.1:35045>: Stream is closed
# 2023-05-04 14:27:17,558 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:52042 remote=tcp://127.0.0.1:35045>: Stream is closed
# 2023-05-04 14:27:17,565 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:51818 remote=tcp://127.0.0.1:35045>: Stream is closed
# 2023-05-04 14:27:17,569 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:51800 remote=tcp://127.0.0.1:35045>: Stream is closed

# %%
client = Client(n_workers=N_WORKERS)
# Out:
# /home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/node.py:183: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 35985 instead
#   warnings.warn(

# %%
# Isolate SIF field only
mf_univariate = deepcopy(mf)
mf_univariate.fields = np.array([mf_univariate.fields[0]])
mf_univariate.n_procs = 1

# Load univariate model
with open(f"../../data/production/models/{year_month_str}/univariate_model.pickle", "rb") as f:
    univariate_matern = pickle.load(f)

# %%
# Make validation predictions
krige = prediction.Predictor(univariate_matern, mf_univariate)
dict_krige = krige.cross_validation(
    0,
    pcoords,
    df_measurement_error,
    ds_covariates,
    num_local_values=NUM_LOCAL_VALUES,
)
ds_krige = dict_krige["ds"]
ds_krige
# Out:
# INFO | root:_compute_prediction_covariance_matrix:518 | Running predictive covariance
# INFO | root:_compute_predictive_covariance_element:574 | Status: s = 0 ...
# INFO | root:_compute_predictive_covariance_element:574 | Status: s = 600 ...
# INFO | root:_compute_predictive_covariance_element:574 | Status: s = 500 ...
# INFO | root:_compute_predictive_covariance_element:574 | Status: s = 400 ...
# INFO | root:_compute_predictive_covariance_element:574 | Status: s = 300 ...
# INFO | root:_compute_predictive_covariance_element:574 | Status: s = 200 ...
# INFO | root:_compute_predictive_covariance_element:574 | Status: s = 100 ...
# INFO | root:_compute_predictive_covariance_element:574 | Status: s = 700 ...
# <xarray.Dataset>
# Dimensions:               (lat: 100, lon: 89)
# Coordinates:
#   * lat                   (lat) float64 36.52 36.57 36.62 ... 41.37 41.42 41.47
#   * lon                   (lon) float64 -104.0 -103.9 -103.9 ... -99.07 -99.02
#     time                  <U10 '2021-10-01'
# Data variables: (12/66)
#     residual_predictions  (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     prediction_error      (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     validity_flag         (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B2                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B3                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B4                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     ...                    ...
#     trend_surface         (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     measurement_error     (lat, lon) float32 nan nan nan nan ... nan nan nan nan
#     predictions           (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     mspe                  (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     scaled_residuals      (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     trend_surface_mspe    (lat, lon) float64 0.0009026 0.0009026 ... 0.0009026
# Attributes:
#     timedeltas:        [0, 1]
#     num_local_values:  150

# %%
# Save multivariate predictive distribution
pd.DataFrame(dict_krige["predictive_mean"]).to_csv(
    f"../../data/production/validation/{year_month_str}/mean_kriging_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)

pd.DataFrame(dict_krige["predictive_covariance_matrix"]).to_csv(
    f"../../data/production/validation/{year_month_str}/covariance_kriging_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)

# %%
# Prepare validation results
df_krige = ds_krige.to_dataframe().reset_index()[["lat", "lon", "predictions", "mspe"]].dropna()

df_test_krige = validation.prepare_validation_results(
    df_krige,
    df_test,
    method="kriging",
    month=year_month_str,
    region=BLOCK_NAME,
)

# Compute QQ-plot quantiles
quantiles_krige = sm.ProbPlot(df_test_krige["ratio"].values)
df_quantiles_krige = pd.DataFrame(
    dict(
        sample=quantiles_krige.sample_quantiles,
        theoretical=quantiles_krige.theoretical_quantiles,
        Method="Kriging",
    )
)

# %% [markdown]
# ## Trend-only

# %%
# Prepare validation results
df_trend = (
    ds_krige.to_dataframe()
    .reset_index()[["lat", "lon", "trend_surface", "trend_surface_mspe"]]
    .dropna()
    .rename(columns={"trend_surface": "predictions", "trend_surface_mspe": "mspe"})
)

df_test_trend = validation.prepare_validation_results(
    df_trend,
    df_test,
    method="Trend surface",
    month=year_month_str,
    region=BLOCK_NAME,
)

# Compute QQ-plot quantiles
quantiles_trend = sm.ProbPlot(df_test_trend["ratio"].values)
df_quantiles_trend = pd.DataFrame(
    dict(
        sample=quantiles_trend.sample_quantiles,
        theoretical=quantiles_trend.theoretical_quantiles,
        Method="Trend surface",
    )
)

# %%
# Save multivariate predictive distribution
df_test_trend["predictions"].to_csv(
    f"../../data/production/validation/{year_month_str}/mean_trend_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)
pd.DataFrame(np.diag(df_test_trend["mspe"].values)).to_csv(
    f"../../data/production/validation/{year_month_str}/covariance_trend_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)

# %% [markdown]
# ## Collect and plot results

# %%
df_validation_results = pd.concat([df_test_trend, df_test_krige, df_test_cokrige], axis=0).reset_index(
    drop=True
)
df_validation_results.to_csv(
    f"../../data/production/validation/{year_month_str}/validation_results_{BLOCK_NAME}.csv"
)
df_validation_results
# Out:
#              Method   Month Region     lat      lon      data  predictions  \
# 0     Trend surface  202110     b2  36.525 -103.625 -0.117012     0.216676
# 1     Trend surface  202110     b2  36.525 -103.575  0.155045     0.218794
# 2     Trend surface  202110     b2  36.525 -101.875  0.422391     0.279073
# 3     Trend surface  202110     b2  36.525 -101.425  0.377359     0.295329
# 4     Trend surface  202110     b2  36.525 -101.375  0.052247     0.297568
# ...             ...     ...    ...     ...      ...       ...          ...
# 2119      Cokriging  202110     b2  41.425 -101.375  0.418129     0.295172
# 2120      Cokriging  202110     b2  41.475 -102.975 -0.184186     0.219189
# 2121      Cokriging  202110     b2  41.475 -102.925 -0.059710     0.218412
# 2122      Cokriging  202110     b2  41.475 -101.425  0.112492     0.291260
# 2123      Cokriging  202110     b2  41.475 -101.375  0.249514     0.293553
#
#           mspe  difference     ratio  covered       INT       DSS
# 0     0.083784   -0.333688 -1.152814     True  1.136588 -1.150532
# 1     0.081800   -0.063749 -0.222894     True  1.123052 -2.453792
# 2     0.112624    0.143319  0.427058     True  1.317763 -2.001323
# 3     0.111207    0.082030  0.245984     True  1.309451 -2.135850
# 4     0.126583   -0.245322 -0.689522     True  1.397043 -1.591416
# ...        ...         ...       ...      ...       ...       ...
# 2119  0.115791    0.122958  0.361341     True  1.336164 -2.025400
# 2120  0.106699   -0.403375 -1.234893     True  1.282631 -0.712786
# 2121  0.106036   -0.278122 -0.854099     True  1.278643 -1.514489
# 2122  0.106672   -0.178767 -0.547348     True  1.282470 -1.938408
# 2123  0.112988   -0.044039 -0.131014     True  1.319889 -2.163313
#
# [2124 rows x 13 columns]

# %%
df_quantiles = pd.concat(
    [df_quantiles_trend, df_quantiles_krige, df_quantiles_cokrige], axis=0
).reset_index(drop=True)
df_quantiles.to_csv(
    f"../../data/production/validation/{year_month_str}/validation_ratio_quantiles_{BLOCK_NAME}.csv"
)

df_quantiles
# Out:
#         sample  theoretical         Method
# 0    -2.642333    -2.986612  Trend surface
# 1    -2.337153    -2.767907  Trend surface
# 2    -2.199963    -2.633033  Trend surface
# 3    -2.172510    -2.533794  Trend surface
# 4    -2.111978    -2.454594  Trend surface
# ...        ...          ...            ...
# 2119  2.397274     2.454594      Cokriging
# 2120  2.606840     2.533794      Cokriging
# 2121  2.756662     2.633033      Cokriging
# 2122  2.838058     2.767907      Cokriging
# 2123  3.476755     2.986612      Cokriging
#
# [2124 rows x 3 columns]

# %%
sns.set_theme(context="paper", style="whitegrid", font_scale=1.3, rc={"lines.markersize": 8})
qq_palette = ["#d95f02", "#7570b3", "#1b9e77"]
methods = ["Trend surface", "Kriging", "Cokriging"]

fig, axes = plt.subplots(1, 4, figsize=(14, 5), constrained_layout=True)

axes[0].axline(xy1=[0, 0], slope=1, linestyle="dotted", color="grey")
qq = sns.scatterplot(
    data=df_quantiles,
    x="theoretical",
    y="sample",
    hue="Method",
    hue_order=methods,
    palette=qq_palette,
    edgecolor="face",
    alpha=0.5,
    ax=axes[0],
)
qq.set(yticks=np.arange(-4, 6, 2))
axes[0].set_xlim(-4, 4)
axes[0].set_ylim(-4, 4)
axes[0].set_aspect(aspect="equal")
axes[0].set_title("Quantile-quantile plot")
axes[0].set_xlabel("Standard Gaussian quantiles")
axes[0].set_ylabel("Standardized differences")

for i, method in enumerate(methods):
    df_group = df_validation_results.loc[df_validation_results["Method"] == method, :]
    field_diff = axes[i + 1].scatter(
        x=df_group["lon"],
        y=df_group["lat"],
        c=df_group["ratio"],
        alpha=0.8,
        cmap=cm.roma_r,
        vmin=-3,
        vmax=3,
    )
    axes[i + 1].set_aspect(aspect="equal")
    axes[i + 1].set_title(method)
    axes[i + 1].set_xlabel("Longitude")
    axes[i + 1].set_ylabel("Latitude")

fig.colorbar(
    field_diff,
    extend="both",
    label="Standardized differences",
    ax=axes[-1],
    cax=axes[-1].inset_axes([1.15, 0, 0.075, 1]),
)

# %%
fig.savefig(
    f"../../figures/cross_validation_{year_month_str}_{BLOCK_NAME}.pdf",
    dpi=300,
    bbox_inches="tight",
)
