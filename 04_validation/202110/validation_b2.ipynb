# %% [markdown]
# # Within-sample validation against withheld validation block
#
# Leave out a block of data and predict the withheld data. Models include cokriging, kriging,
# and trend-only prediction

# %%
import sys

sys.path.insert(0, "../../source")

# %%
from copy import deepcopy
import pickle
import numpy as np
import pandas as pd
import xarray as xr
import statsmodels.api as sm

import matplotlib.pyplot as plt
import seaborn as sns

import plot
import prediction
import validation

# %%
from dask.distributed import Client

# NOTE: update depending on which node is used
N_WORKERS = 84
client = Client(n_workers=N_WORKERS)
# Out:
# /home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/node.py:183: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 37963 instead
#   warnings.warn(
# 2023-06-13 13:51:42,345 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-1o0eap27', purging
# 2023-06-13 13:51:42,345 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-s74aza4t', purging
# 2023-06-13 13:51:42,345 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-7e76moyq', purging
# 2023-06-13 13:51:42,345 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-gx7198v0', purging
# 2023-06-13 13:51:42,345 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-3c29lck4', purging
# 2023-06-13 13:51:42,345 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-9fsiau9l', purging
# 2023-06-13 13:51:42,345 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-jnvz4lmv', purging
# 2023-06-13 13:51:42,345 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-iiqyneq6', purging
# 2023-06-13 13:51:42,346 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-jm9a988d', purging
# 2023-06-13 13:51:42,346 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-48k9raro', purging
# 2023-06-13 13:51:42,346 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-o0nq7b1p', purging
# 2023-06-13 13:51:42,346 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-aj70hx93', purging
# 2023-06-13 13:51:42,346 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-vmek3bs7', purging
# 2023-06-13 13:51:42,346 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-9iswhjug', purging
# 2023-06-13 13:51:42,346 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-nwvzl4zw', purging
# 2023-06-13 13:51:42,346 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-zm6romx7', purging
# 2023-06-13 13:51:42,346 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ucaceamv', purging
# 2023-06-13 13:51:42,346 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-uc246jzx', purging
# 2023-06-13 13:51:42,346 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ctjuv8yi', purging
# 2023-06-13 13:51:42,346 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-tlbrhm4s', purging
# 2023-06-13 13:51:42,346 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-clxksdlh', purging
# 2023-06-13 13:51:42,346 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-w2zavugz', purging
# 2023-06-13 13:51:42,347 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-9dff7amv', purging
# 2023-06-13 13:51:42,347 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-tsxglfry', purging
# 2023-06-13 13:51:42,347 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-13mi7k51', purging
# 2023-06-13 13:51:42,347 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-msen0qd6', purging
# 2023-06-13 13:51:42,347 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-728y8jcs', purging
# 2023-06-13 13:51:42,347 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-r0y5i53s', purging
# 2023-06-13 13:51:42,347 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-0fgbjs_i', purging
# 2023-06-13 13:51:42,347 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-vszggkna', purging
# 2023-06-13 13:51:42,347 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-vvreet70', purging
# 2023-06-13 13:51:42,347 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-10twv3v_', purging
# 2023-06-13 13:51:42,347 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-x46dks4r', purging
# 2023-06-13 13:51:42,347 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-cfyjcn4r', purging
# 2023-06-13 13:51:42,347 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-v6dua7mc', purging
# 2023-06-13 13:51:42,347 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-2n93_iks', purging
# 2023-06-13 13:51:42,347 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-k8q5hi9x', purging
# 2023-06-13 13:51:42,348 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-yqbna331', purging
# 2023-06-13 13:51:42,348 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-e3lovtid', purging
# 2023-06-13 13:51:42,348 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-5fjek82y', purging
# 2023-06-13 13:51:42,348 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-y796apha', purging
# 2023-06-13 13:51:42,348 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-n5l9hp9n', purging
# 2023-06-13 13:51:42,348 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-6nyfk8sy', purging
# 2023-06-13 13:51:42,348 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-39624xzk', purging
# 2023-06-13 13:51:42,348 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-jjcqsw7v', purging
# 2023-06-13 13:51:42,348 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-jc1s0j5i', purging
# 2023-06-13 13:51:42,348 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-8_uygj09', purging
# 2023-06-13 13:51:42,348 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-cwqz01tj', purging
# 2023-06-13 13:51:42,348 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ra99th8w', purging
# 2023-06-13 13:51:42,348 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-66rt85xk', purging
# 2023-06-13 13:51:42,348 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-nrgyx63j', purging
# 2023-06-13 13:51:42,348 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-zpg1f80x', purging
# 2023-06-13 13:51:42,349 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-jnnp926c', purging
# 2023-06-13 13:51:42,349 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-o02n7p30', purging
# 2023-06-13 13:51:42,349 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ptyd7bwc', purging
# 2023-06-13 13:51:42,349 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-nobo0ygd', purging
# 2023-06-13 13:51:42,349 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-16u1vu1x', purging
# 2023-06-13 13:51:42,349 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-i1_6zser', purging
# 2023-06-13 13:51:42,349 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-w2mb5rl9', purging
# 2023-06-13 13:51:42,349 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-9g0_gnn7', purging
# 2023-06-13 13:51:42,349 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ah_jmktk', purging
# 2023-06-13 13:51:42,349 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-li01wxte', purging
# 2023-06-13 13:51:42,349 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-jtjroddd', purging
# 2023-06-13 13:51:42,349 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-q74n4yyr', purging
# 2023-06-13 13:51:42,349 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-zjz7c3xp', purging
# 2023-06-13 13:51:42,349 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-5u34y8d8', purging
# 2023-06-13 13:51:42,350 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-_1ob6otc', purging
# 2023-06-13 13:51:42,350 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-1svjpjtg', purging
# 2023-06-13 13:51:42,350 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ftzdpcns', purging
# 2023-06-13 13:51:42,350 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-cnblghqs', purging
# 2023-06-13 13:51:42,350 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-m_e4ee2f', purging
# 2023-06-13 13:51:42,350 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-_pbrcssx', purging
# 2023-06-13 13:51:42,350 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-iqayyu12', purging
# 2023-06-13 13:51:42,350 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-jfj43xg0', purging
# 2023-06-13 13:51:42,350 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-xeubcu5i', purging
# 2023-06-13 13:51:42,350 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-7pmqttl9', purging
# 2023-06-13 13:51:42,350 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-3qkzxltl', purging
# 2023-06-13 13:51:42,350 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-sbc0j9su', purging
# 2023-06-13 13:51:42,350 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-p0uijvb3', purging
# 2023-06-13 13:51:42,350 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-xru4xshz', purging
# 2023-06-13 13:51:42,350 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ck8_jdc9', purging
# 2023-06-13 13:51:42,351 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-_mnow9e1', purging
# 2023-06-13 13:51:42,351 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-l5we9pts', purging
# 2023-06-13 13:51:42,351 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-c55g3t5q', purging

# %%
# number of nearest observations used in point predictions
NUM_LOCAL_VALUES = 150

# data selection
YEAR = 2021
MONTH = 10
# XCO2 months ahead of SIF
OFFSET = 1

year_month_str = f"{YEAR}0{MONTH}" if MONTH < 10 else f"{YEAR}{MONTH}"

# %%
month_xco2 = MONTH + OFFSET
date_sif = f"{YEAR}-{MONTH}-01"
date_xco2 = f"{YEAR}-{month_xco2}-01"

with xr.open_dataset(
    "../../data/intermediate/OCO2_005deg_monthly_north_america_with_basis.nc4"
) as ds:
    basis_vars = [x for x in list(ds.keys()) if x.startswith("B")]
    ds_sif = ds[["sif", "sif_var"] + basis_vars].sel(time=f"{YEAR}-{MONTH}").squeeze()

# %%
BLOCK_NAME = "b2"
block_conditions = (
    (ds_sif["lon"] > -104)
    & (ds_sif["lon"] < -99)
    & (ds_sif["lat"] > 36.5)
    & (ds_sif["lat"] < 41.5)
)
ds_test = ds_sif.where(block_conditions)

plot.plot_da(ds_test["sif"])

# %%
df_test = (
    ds_test.to_dataframe()
    .dropna(subset="sif")
    .reset_index()[["lat", "lon", "sif", "sif_var"] + basis_vars]
    .rename(columns={"sif": "data", "sif_var": "me_variance"})
)
df_me_variance = df_test.loc[:, ["lat", "lon", "me_variance"]]
df_test = df_test.drop(columns="me_variance")
ds_covariates = (
    df_test.set_index(["lat", "lon"]).to_xarray().drop_vars(["data", "B1", "B10", "B20"])
)
df_test = df_test.loc[:, ["lat", "lon", "data"]]
pcoords = df_test.loc[:, ["lat", "lon"]]
df_test.to_csv(f"../../data/intermediate/validation/{year_month_str}/df_test_{BLOCK_NAME}.csv")
df_test
# Out:
#         lat      lon      data
# 0    36.525 -103.625 -0.117012
# 1    36.525 -103.575  0.155045
# 2    36.525 -101.875  0.422391
# 3    36.525 -101.425  0.377359
# 4    36.525 -101.375  0.052247
# ..      ...      ...       ...
# 703  41.425 -101.375  0.418129
# 704  41.475 -102.975 -0.184186
# 705  41.475 -102.925 -0.059710
# 706  41.475 -101.425  0.112492
# 707  41.475 -101.375  0.249514
#
# [708 rows x 3 columns]

# %%
ds_covariates
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 100, lon: 89)
# Coordinates:
#   * lat      (lat) float64 36.52 36.57 36.62 36.67 ... 41.32 41.37 41.42 41.47
#   * lon      (lon) float64 -104.0 -103.9 -103.9 -103.8 ... -99.12 -99.07 -99.02
# Data variables: (12/57)
#     B2       (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B3       (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B4       (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B5       (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B6       (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B7       (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     ...       ...
#     B55      (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B56      (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B57      (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B58      (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B59      (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     B60      (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan

# %%
sns.histplot(df_test["data"].values)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ## Cokriging

# %%
# Load multifield and model objects
with open(f"../../data/intermediate/models/{year_month_str}/fields.pickle", "rb") as f:
    mf = pickle.load(f)

with open(f"../../data/intermediate/models/{year_month_str}/bivariate_model.pickle", "rb") as f:
    bivariate_matern = pickle.load(f)

# %%
# Make validation predictions
cokrige = prediction.Predictor(bivariate_matern, mf)
dict_cokrige = cokrige.validation_prediction(
    0,
    pcoords,
    df_me_variance,
    ds_covariates,
    num_local_values=NUM_LOCAL_VALUES,
)
ds_cokrige = dict_cokrige["ds"]
ds_cokrige
# Out:
# INFO | root:_compute_prediction_covariance_matrix:475 | Running predictive covariance
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 0 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 600 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 400 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 500 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 300 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 200 ...
# 2023-06-13 13:56:27,564 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.23 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:27,646 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.28 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:27,774 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.34 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:27,858 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.39 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:27,953 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.44 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:27,994 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.26 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:28,053 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.53 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:28,127 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.34 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:28,146 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.61 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:28,164 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.36 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:28,250 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.66 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:28,262 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.39 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:28,372 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.45 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:28,480 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.51 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:28,572 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.57 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:28,678 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.63 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:29,416 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.26 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:29,530 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.33 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:29,618 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.42 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:29,747 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.52 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:29,809 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.56 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:29,874 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.22 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:29,910 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.65 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:30,012 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.29 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:30,070 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.31 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:30,190 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.38 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:30,284 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.45 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:30,379 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.51 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:30,498 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.57 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:30,523 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.21 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:30,580 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.60 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:30,612 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.28 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:30,675 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.67 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:30,721 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.36 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:30,812 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.43 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:30,917 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.51 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:31,040 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.55 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:31,114 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.60 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:31,211 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.64 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:31,958 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.28 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:32,073 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.37 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:32,146 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.42 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:32,252 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.48 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:32,361 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.52 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:32,479 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.61 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:32,559 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.67 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:32,644 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.21 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:32,818 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.25 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:33,045 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.29 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:33,046 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.29 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:33,213 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.31 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:33,251 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.31 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:33,354 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.33 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:33,466 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.33 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:33,573 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.35 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:33,754 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.36 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:33,872 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.38 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:33,935 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.38 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:34,096 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.44 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:34,136 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.46 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:34,257 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.50 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:34,335 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.55 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:34,435 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.60 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:34,549 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.20 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:34,570 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.68 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:34,608 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.22 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:34,729 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.30 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:34,808 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.35 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:34,917 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.45 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,058 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.56 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,114 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.60 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,135 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.24 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,210 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.66 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,234 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.29 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,290 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.22 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,307 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.71 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,367 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.37 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,410 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.27 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,415 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.77 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,436 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.42 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,482 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.31 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,539 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.23 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,545 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.48 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,579 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.33 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,630 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.28 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,633 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.53 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,643 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.24 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,712 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.40 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,727 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.32 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,735 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.59 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,761 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.31 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,793 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.46 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,829 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.39 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,847 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.65 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,858 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.37 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,880 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.49 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,935 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.46 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,942 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.44 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:35,995 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.58 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:36,049 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.56 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:36,071 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.52 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:36,091 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.63 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:36,128 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.63 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:36,141 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.57 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:36,240 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.65 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:37,275 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.21 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:37,393 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.26 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:37,522 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.34 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:37,585 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.38 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:37,611 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.25 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:37,644 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.26 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:37,664 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.26 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:37,672 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.44 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:37,745 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.31 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:37,748 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.33 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:37,819 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.50 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:37,848 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.36 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:37,855 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.38 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:37,872 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.53 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:37,944 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.43 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:37,974 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.48 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:37,999 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.60 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:38,041 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.51 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:38,045 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.53 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:38,077 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.65 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:38,127 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.56 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:38,135 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.22 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:38,149 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.59 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:38,236 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.62 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:38,243 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.26 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:38,255 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.66 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:38,336 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.65 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:38,340 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.31 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:38,361 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.22 GiB -- Worker memory limit: 5.99 GiB
# ...
# 2023-06-13 13:56:46,227 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.49 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:46,271 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.68 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:46,286 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.58 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:46,335 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.54 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:46,420 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.67 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:46,426 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.60 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:46,520 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.68 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:47,465 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.21 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:47,558 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.23 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:47,618 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.27 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:47,725 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.35 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:47,821 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.40 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:47,923 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.46 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:48,028 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.54 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:48,063 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.20 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:48,136 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.60 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:48,159 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.24 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:48,231 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.66 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:48,265 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.30 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:48,351 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.36 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:48,461 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.46 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:48,556 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.52 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:48,672 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.61 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:48,752 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.68 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:56:48,891 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.79 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:57:06,625 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.24 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:57:06,670 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.26 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:57:06,725 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.35 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:57:06,770 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.33 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:57:06,841 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.46 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:57:06,900 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.43 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:57:06,911 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.52 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:57:07,012 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.63 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:57:07,015 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.54 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:57:07,026 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.35 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:57:07,069 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.37 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:57:07,083 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.61 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:57:07,177 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.49 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:57:07,370 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.67 GiB -- Worker memory limit: 5.99 GiB
# 2023-06-13 13:57:07,371 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 4.67 GiB -- Worker memory limit: 5.99 GiB
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 700 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 100 ...
# <xarray.Dataset>
# Dimensions:               (lat: 100, lon: 89)
# Coordinates:
#   * lat                   (lat) float64 36.52 36.57 36.62 ... 41.37 41.42 41.47
#   * lon                   (lon) float64 -104.0 -103.9 -103.9 ... -99.07 -99.02
#     time                  <U10 '2021-10-01'
# Data variables: (12/66)
#     residual_predictions  (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     residual_uncertainty  (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     validity_flag         (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B2                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B3                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B4                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     ...                    ...
#     trend_surface         (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     me_variance           (lat, lon) float32 nan nan nan nan ... nan nan nan nan
#     predictions           (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     scaled_residuals      (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     trend_surface_rmspe   (lat, lon) float32 0.02319 0.02319 ... 0.02319 0.02319
#     rmspe                 (lat, lon) float64 nan nan nan nan ... nan nan nan nan
# Attributes:
#     timedeltas:        [0, 1]
#     num_local_values:  150

# %%
# Save multivariate predictive distribution
pd.DataFrame(dict_cokrige["predictive_mean"]).to_csv(
    f"../../data/intermediate/validation/{year_month_str}/mean_cokriging_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)

pd.DataFrame(dict_cokrige["predictive_covariance_matrix"]).to_csv(
    f"../../data/intermediate/validation/{year_month_str}/covariance_cokriging_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)

# %%
# Prepare validation results
df_cokrige = (
    ds_cokrige.to_dataframe().reset_index()[["lat", "lon", "predictions", "rmspe"]].dropna()
)

df_test_cokrige = validation.prepare_validation_results(
    df_cokrige,
    df_test,
    method="cokriging",
    month=year_month_str,
    region=BLOCK_NAME,
)

# Compute QQ-plot quantiles
quantiles_cokrige = sm.ProbPlot(df_test_cokrige["ratio"].values)
df_quantiles_cokrige = pd.DataFrame(
    dict(
        sample=quantiles_cokrige.sample_quantiles,
        theoretical=quantiles_cokrige.theoretical_quantiles,
        Method="Cokriging",
    )
)

# %% [markdown]
# ## Kriging

# %%
client.close()
# Out:
# 2023-06-13 13:58:06,739 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48612 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:06,754 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48420 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:06,756 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48740 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:06,775 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48290 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:06,795 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48534 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:06,800 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48472 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:06,808 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48030 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:06,850 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48286 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:06,963 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48426 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:06,963 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48224 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:06,964 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48152 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:06,972 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48720 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:07,035 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48730 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:07,043 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48488 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:07,120 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48746 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:07,176 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48278 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:07,189 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48706 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:07,225 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48060 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:07,277 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48062 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:07,590 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48624 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:07,677 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48322 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:07,700 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48626 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:07,709 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48562 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:07,714 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48762 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:07,725 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48102 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:07,742 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48382 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:07,757 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# ...
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48650 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:08,047 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48292 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:08,051 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48330 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:08,056 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48344 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:08,055 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48574 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:08,056 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48256 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:08,058 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48264 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:08,104 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48474 remote=tcp://127.0.0.1:42975>: Stream is closed
# 2023-06-13 13:58:08,105 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/worker.py", line 1205, in heartbeat
#     response = await retry_operation(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48284 remote=tcp://127.0.0.1:42975>: Stream is closed

# %%
client = Client(n_workers=N_WORKERS)
# Out:
# /home/jj829/miniconda3/envs/geostat/lib/python3.9/site-packages/distributed/node.py:183: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 41941 instead
#   warnings.warn(

# %%
# Isolate SIF field only
mf_univariate = deepcopy(mf)
mf_univariate.fields = np.array([mf_univariate.fields[0]])
mf_univariate.n_procs = 1

# Load univariate model
with open(
    f"../../data/intermediate/models/{year_month_str}/univariate_model.pickle", "rb"
) as f:
    univariate_matern = pickle.load(f)

# %%
# Make validation predictions
krige = prediction.Predictor(univariate_matern, mf_univariate)
dict_krige = krige.validation_prediction(
    0,
    pcoords,
    df_me_variance,
    ds_covariates,
    num_local_values=NUM_LOCAL_VALUES,
)
ds_krige = dict_krige["ds"]
ds_krige
# Out:
# INFO | root:_compute_prediction_covariance_matrix:475 | Running predictive covariance
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 0 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 500 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 600 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 400 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 200 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 300 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 100 ...
# INFO | root:_compute_predictive_covariance_element:539 | Status: a = 700 ...
# <xarray.Dataset>
# Dimensions:               (lat: 100, lon: 89)
# Coordinates:
#   * lat                   (lat) float64 36.52 36.57 36.62 ... 41.37 41.42 41.47
#   * lon                   (lon) float64 -104.0 -103.9 -103.9 ... -99.07 -99.02
#     time                  <U10 '2021-10-01'
# Data variables: (12/66)
#     residual_predictions  (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     residual_uncertainty  (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     validity_flag         (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B2                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B3                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     B4                    (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     ...                    ...
#     trend_surface         (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     me_variance           (lat, lon) float32 nan nan nan nan ... nan nan nan nan
#     predictions           (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     scaled_residuals      (lat, lon) float64 nan nan nan nan ... nan nan nan nan
#     trend_surface_rmspe   (lat, lon) float32 0.02319 0.02319 ... 0.02319 0.02319
#     rmspe                 (lat, lon) float64 nan nan nan nan ... nan nan nan nan
# Attributes:
#     timedeltas:        [0, 1]
#     num_local_values:  150

# %%
# Save multivariate predictive distribution
pd.DataFrame(dict_krige["predictive_mean"]).to_csv(
    f"../../data/intermediate/validation/{year_month_str}/mean_kriging_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)

pd.DataFrame(dict_krige["predictive_covariance_matrix"]).to_csv(
    f"../../data/intermediate/validation/{year_month_str}/covariance_kriging_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)

# %%
# Prepare validation results
df_krige = (
    ds_krige.to_dataframe().reset_index()[["lat", "lon", "predictions", "rmspe"]].dropna()
)

df_test_krige = validation.prepare_validation_results(
    df_krige,
    df_test,
    method="kriging",
    month=year_month_str,
    region=BLOCK_NAME,
)

# Compute QQ-plot quantiles
quantiles_krige = sm.ProbPlot(df_test_krige["ratio"].values)
df_quantiles_krige = pd.DataFrame(
    dict(
        sample=quantiles_krige.sample_quantiles,
        theoretical=quantiles_krige.theoretical_quantiles,
        Method="Kriging",
    )
)

# %% [markdown]
# ## Trend-only

# %%
# Prepare validation results
df_trend = (
    ds_krige.to_dataframe()
    .reset_index()[["lat", "lon", "trend_surface", "trend_surface_rmspe"]]
    .dropna()
    .rename(columns={"trend_surface": "predictions", "trend_surface_rmspe": "rmspe"})
)

df_test_trend = validation.prepare_validation_results(
    df_trend,
    df_test,
    method="Trend surface",
    month=year_month_str,
    region=BLOCK_NAME,
)

# Compute QQ-plot quantiles
quantiles_trend = sm.ProbPlot(df_test_trend["ratio"].values)
df_quantiles_trend = pd.DataFrame(
    dict(
        sample=quantiles_trend.sample_quantiles,
        theoretical=quantiles_trend.theoretical_quantiles,
        Method="Trend surface",
    )
)

# %%
# Save multivariate predictive distribution
df_test_trend["predictions"].to_csv(
    f"../../data/intermediate/validation/{year_month_str}/mean_trend_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)
pd.DataFrame(np.diag(df_test_trend["rmspe"].values ** 2)).to_csv(
    f"../../data/intermediate/validation/{year_month_str}/covariance_trend_{BLOCK_NAME}.csv",
    header=None,
    index=None,
)

# %% [markdown]
# ## Collect results

# %%
df_validation_results = pd.concat(
    [df_test_trend, df_test_krige, df_test_cokrige], axis=0
).reset_index(drop=True)
df_validation_results.to_csv(
    f"../../data/intermediate/validation/{year_month_str}/validation_results_{BLOCK_NAME}.csv"
)
df_validation_results
# Out:
#              Method   Month Region     lat      lon      data  predictions  \
# 0     Trend surface  202110     b2  36.525 -103.625 -0.117012     0.216676
# 1     Trend surface  202110     b2  36.525 -103.575  0.155045     0.218794
# 2     Trend surface  202110     b2  36.525 -101.875  0.422391     0.279073
# 3     Trend surface  202110     b2  36.525 -101.425  0.377359     0.295329
# 4     Trend surface  202110     b2  36.525 -101.375  0.052247     0.297568
# ...             ...     ...    ...     ...      ...       ...          ...
# 2119      Cokriging  202110     b2  41.425 -101.375  0.418129     0.297766
# 2120      Cokriging  202110     b2  41.475 -102.975 -0.184186     0.217726
# 2121      Cokriging  202110     b2  41.475 -102.925 -0.059710     0.217045
# 2122      Cokriging  202110     b2  41.475 -101.425  0.112492     0.295009
# 2123      Cokriging  202110     b2  41.475 -101.375  0.249514     0.297491
#
#          rmspe  difference     ratio       INT       DSS
# 0     0.288824    0.333688  1.155331  1.134111 -1.149084
# 1     0.285792    0.063749  0.223062  1.122205 -2.455225
# 2     0.338182   -0.143319 -0.423792  1.327921 -1.988745
# 3     0.332977   -0.082030 -0.246354  1.307483 -2.138675
# 4     0.355788    0.245322  0.689516  1.397057 -1.591406
# ...        ...         ...       ...       ...       ...
# 2119  0.345820   -0.120363 -0.348052  1.357914 -2.002533
# 2120  0.331104    0.401912  1.213852  1.300131 -0.737206
# 2121  0.330501    0.276755  0.837382  1.297760 -1.513085
# 2122  0.330536    0.182517  0.552184  1.297901 -1.909169
# 2123  0.340402    0.047977  0.140943  1.336638 -2.135393
#
# [2124 rows x 12 columns]

# %%
df_quantiles = pd.concat(
    [df_quantiles_trend, df_quantiles_krige, df_quantiles_cokrige], axis=0
).reset_index(drop=True)
df_quantiles.to_csv(
    f"../../data/intermediate/validation/{year_month_str}/validation_ratio_quantiles_{BLOCK_NAME}.csv"
)

df_quantiles
# Out:
#         sample  theoretical         Method
# 0    -3.593804    -2.986612  Trend surface
# 1    -2.991442    -2.767907  Trend surface
# 2    -2.931467    -2.633033  Trend surface
# 3    -2.691520    -2.533794  Trend surface
# 4    -2.504189    -2.454594  Trend surface
# ...        ...          ...            ...
# 2119  1.983776     2.454594      Cokriging
# 2120  2.007706     2.533794      Cokriging
# 2121  2.058580     2.633033      Cokriging
# 2122  2.185675     2.767907      Cokriging
# 2123  2.454563     2.986612      Cokriging
#
# [2124 rows x 3 columns]
